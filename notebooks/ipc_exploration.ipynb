# %% [markdown]
# # IPC API Exploration
# This notebook explores the IPC API attempting to understand what data is available and the best way to work with it.

# %%
import pandas as pd
import geopandas as gpd
import requests
from datetime import date
import plotly.express as px
import numpy as np

# %% [markdown]
# ## Documentation Links:
# - API Documentaiton: https://docs.api.ipcinfo.org/#/developers/
# - General info: https://www.ipcinfo.org/ipc-country-analysis/api/
# - Latest Analysis: https://www.ipcinfo.org/ipc-country-analysis/en/

# %%
# DELETE THIS CELL BEFORE PUBLISHING
ipc_api_key = "&key=YOUR-KEY-HERE"

# %% [markdown]
# ## Things I'm learning
# - API seems to go back to 2017 (verified on Country endpoint)
# - There are five endpoints in the IPC API:
#   - Analysis
#   - Country
#   - Areas
#   - Points
#   - Icons
# ### Analysis Endpoint
# So Analysis returns reports that the IPC has published. It seems that it's a more or less a publication list going back to 2017.
#
# ### Country Endpoint
# Country returns country level food security data the returned data includes population in each IPC Category.
#
# ### Areas Endpoint
# Areas returns the data for areas that the IPC has defined for each country. These do not match admin boundaries used by FEWSNET, but there might be come cross over. Additionally, it doesn't seem that there are geographic boundaries available for the titles of the areas referenced in this endpoint. I'm currently requesting more info from IPC on this. I've included histograms of how often each area is measured and how many measurements per year are available at this endpoint.
#
# ### Points Endpoint
# Points endpoint is the same as areas and country endpoint, but it references analysis that have been done at a point level. This is usually at the scene of a disaster event or an urban center. There is an option to query this endpoint in a way that returns geojson data (vs. json), but there are only about 150 analysis of this type.
#
# ### Icons Endpoint
# Haven't explored yet, but will likely contain info on what they convey on maps with icons, which is usually where humanitarian assistance was provided and impacted results accuracy.
#
# ## General
# There might be ways to query the endpoint for more detailed information or other information generally if you are naming report or area of interest. Still exploring this.

# %%
url_base = "https://api.ipcinfo.org/"

def get_ipc_data(endpoint, format):
    request = requests.get(url=url_base+endpoint+ipc_api_key)
    print(request)
    #  print ("length is " + str(len(request.json()["dataset"])))
    if format == "pd":
        return pd.DataFrame(request.json())
    elif format == "json":
        return request.json()
    elif format == "gpd":
        return gpd.GeoDataFrame(request.json())
    else:
        return request.text

# %%
allcountry_df = get_ipc_data("country?format=json&type=A", "pd")
allcountry_df
# Out:
# <Response [200]>
#                                                  title country condition  \
# 0                    Acute Food Insecurity August 2022      BI         A
# 1                    Acute Food Insecurity August 2022      SO         A
# 2      Acute Food Insecurity July 2022 (Grand Sud Est)      MG         A
# 3                Acute Food Insecurity July 2022 (LRA)      KE         A
# 4                      Acute Food Insecurity June 2022      LS         A
# ..                                                 ...     ...       ...
# 125                    Acute Food Insecurity July 2017      SO         A
# 126      Acute Food Insecurity June 2017 (15ème Cycle)      CD         A
# 127            Acute Food Insecurity May 2017 (Sindh)       PK         A
# 128      Acute Food Insecurity March 2017 (Projection)      YE         A
# 129  Acute Food Insecurity February 2017 (12ème Cycle)      CF         A
#
#            id  estimated_population      from        to period  year  \
# 0    26178025              12045234  Oct 2022  Dec 2022      P  2022
# 1    26190751              16384726  Oct 2022  Dec 2022      P  2022
# 2    26138091              29611714  Aug 2022  Oct 2022      C  2022
# 3    26258568              54986000  Oct 2022  Dec 2022      P  2022
# 4    26094569               2104715  Oct 2022  Mar 2023      P  2022
# ..        ...                   ...       ...       ...    ...   ...
# 125  12511433              12327530  Aug 2017  Dec 2017      P  2017
# 126  12507475              78368000  Jun 2017  Dec 2017      C  2017
# 127  12174517             197525005  Feb 2017  Aug 2017      C  2017
# 128  12184859              28235000  Mar 2017  Jul 2017      P  2017
# 129  12135625               5711072  Feb 2017  May 2017      C  2017
#
#                                                 phases
# 0    [{'phase': 1, 'population': 6981059, 'percenta...
# 1    [{'phase': 1, 'population': 6568556, 'percenta...
# 2    [{'phase': 1, 'population': 188735, 'percentag...
# 3    [{'phase': 1, 'population': 5370418, 'percenta...
# 4    [{'phase': 1, 'population': 654668, 'percentag...
# ..                                                 ...
# 125  [{'phase': 1, 'population': 6096530, 'percenta...
# 126  [{'phase': 1, 'population': 0, 'percentage': 0...
# 127  [{'phase': 1, 'population': 1476518, 'percenta...
# 128  [{'phase': 1, 'population': 5128620, 'percenta...
# 129  [{'phase': 1, 'population': 1038686, 'percenta...
#
# [130 rows x 10 columns]

# %%
all_analysis_df = get_ipc_data("analyses?format=json&type=A", "pd")
all_analysis_df
# Out:
# <Response [200]>
#            id                                              title  \
# 0    12135258  Burundi - Acute Food Insecurity March 2017 (20...
# 1    12135625  Central African Republic - Acute Food Insecuri...
# 2    12138309  Guatemala - Acute Food Insecurity July 2017 (D...
# 3    12140917        Haiti - Acute Food Insecurity February 2017
# 4    12144729         Eswatini - Acute Food Insecurity July 2017
# ..        ...                                                ...
# 192  26096991           Zambia - Acute Food Insecurity June 2022
# 193  26138091  Madagascar - Acute Food Insecurity July 2022 (...
# 194  26178025        Burundi - Acute Food Insecurity August 2022
# 195  26190751        Somalia - Acute Food Insecurity August 2022
# 196  26258568      Kenya - Acute Food Insecurity July 2022 (LRA)
#
#                                                   link country  year  \
# 0    http://www.ipcinfo.org/ipc-country-analysis/de...      BI  2017
# 1    http://www.ipcinfo.org/ipc-country-analysis/de...      CF  2017
# 2    http://www.ipcinfo.org/ipc-country-analysis/de...      GT  2017
# 3    http://www.ipcinfo.org/ipc-country-analysis/de...      HT  2017
# 4    http://www.ipcinfo.org/ipc-country-analysis/de...      SZ  2017
# ..                                                 ...     ...   ...
# 192  https://www.ipcinfo.org/ipc-country-analysis/d...      ZM  2022
# 193  https://www.ipcinfo.org/ipc-country-analysis/d...      MG  2022
# 194  https://www.ipcinfo.org/ipc-country-analysis/d...      BI  2022
# 195  https://www.ipcinfo.org/ipc-country-analysis/d...      SO  2022
# 196  https://www.ipcinfo.org/ipc-country-analysis/d...      KE  2022
#
#     condition     created    modified
# 0           A  2017-11-20  2022-02-15
# 1           A  2017-11-20  2022-08-17
# 2           A  2017-11-20  2022-02-15
# 3           A  2017-11-20  2022-02-15
# 4           A  2017-11-20  2022-02-15
# ..        ...         ...         ...
# 192         A  2022-08-09  2022-08-30
# 193         A  2022-08-16  2022-09-16
# 194         A  2022-08-31  2022-10-04
# 195         A  2022-09-11  2022-10-05
# 196         A  2022-09-15  2022-09-29
#
# [197 rows x 8 columns]

# %%
all_areas_df = get_ipc_data("areas?format=json&type=A", "pd")
all_areas_df
# Out:
# <Response [200]>
#             id  estimated_population period      from        to    color  \
# 0     12135272                906391      C  Apr 2017  May 2017  #E67800
# 1     12135266               1772906      C  Apr 2017  May 2017  #E67800
# 2     12135264                238111      C  Apr 2017  May 2017  #E67800
# 3     12135274               1171450      C  Apr 2017  May 2017  #FAE61E
# 4     12135260                651193      C  Apr 2017  May 2017  #C80000
# ...        ...                   ...    ...       ...       ...      ...
# 7592  26258593                340671      C  Jul 2022  Sep 2022  #FAE61E
# 7593  26258589                315943      C  Jul 2022  Sep 2022  #E67800
# 7594  26258597                133595      C  Jul 2022  Sep 2022  #E67800
# 7595  26258599                926976      C  Jul 2022  Sep 2022  #E67800
# 7596  26258601                781263      C  Jul 2022  Sep 2022  #E67800
#
#         anl_id                   title  overall_phase  \
# 0     12135258    Dépressions de l`est              3
# 1     12135258  Plateaux secs de l`est              3
# 2     12135258                Buragane              3
# 3     12135258         Crête congo nil              2
# 4     12135258     Dépressions du nord              4
# ...        ...                     ...            ...
# 7592  26258568                   Taita              2
# 7593  26258568              TANA RIVER              3
# 7594  26258568                 Tharaka              3
# 7595  26258568                 Turkana              3
# 7596  26258568                   Wajir              3
#
#                                                  phases country  year  \
# 0     [{'phase': 1, 'population': 271917, 'percent':...      BI  2017
# 1     [{'phase': 1, 'population': 354581, 'percent':...      BI  2017
# 2     [{'phase': 2, 'population': 83339, 'percent': ...      BI  2017
# 3     [{'phase': 4, 'population': 58573, 'percent': ...      BI  2017
# 4     [{'phase': 4, 'population': 130239, 'percent':...      BI  2017
# ...                                                 ...     ...   ...
# 7592  [{'phase': 1, 'population': 170336, 'percent':...      KE  2022
# 7593  [{'phase': 1, 'population': 31594, 'percent': ...      KE  2022
# 7594  [{'phase': 1, 'population': 46758, 'percent': ...      KE  2022
# 7595  [{'phase': 5, 'population': 0, 'percent': 0, '...      KE  2022
# 7596  [{'phase': 1, 'population': 78126, 'percent': ...      KE  2022
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 0            A                   271918                     0.30
# 1            A                   709163                     0.40
# 2            A                    47623                     0.20
# 3            A                   222575                     0.19
# 4            A                   293037                     0.45
# ...        ...                      ...                      ...
# 7592         A                        0                     0.00
# 7593         A                        0                     0.00
# 7594         A                        0                     0.00
# 7595         A                        0                     0.00
# 7596         A                        0                     0.00
#
# [7597 rows x 15 columns]

# %%
# create an array of all unique values in all_areas_df[]
unique = all_areas_df["title"].unique()
len(unique)
# Out:
# 2277

# %%
# create an array of how many times each unique value appears in all_areas_df[]
counts = all_areas_df["title"].value_counts()
counts
# Out:
# Banadir        13
# Mvolo          10
# Malakal        10
# Nzara          10
# Nyirol         10
#                ..
# At talh         1
# At tawahi       1
# Ayn             1
# Brum mayfah     1
# Vondrozo        1
# Name: title, Length: 2277, dtype: int64

# %%
# create a histogram for unique values in counts[] using plotly
count_hist = px.histogram(counts, x=counts)
# change title of x axis to hello
count_hist.update_xaxes(title_text="Number of times a region was measured")
count_hist.show()

# %%
year_hist = px.histogram(all_areas_df["year"], x=all_areas_df["year"])
year_hist.update_xaxes(title_text="Measurement Year")
year_hist

# %%
# points endpoint is unique in that it allows you to query in geojson format
all_points = get_ipc_data("points?format=geojson&type=A", "json")
# make geodataframe from all_points["features"] geometry is in "coordinates"
all_points_gdf = gpd.GeoDataFrame.from_features(all_points["features"])
all_points_gdf.crs = "EPSG:4326"
all_points_gdf
# Out:
# <Response [200]>
#                       geometry    aar_id  confidence_level ipc_period  \
# 0     POINT (34.20533 1.05688)  18724768                 0          C
# 1     POINT (32.77218 0.38805)  18724770                 0          C
# 2    POINT (30.92099 -0.91005)  18724774                 0          C
# 3    POINT (30.74095 -1.06385)  18724776                 0          C
# 4     POINT (30.66085 0.18474)  18724766                 0          C
# ..                         ...       ...               ...        ...
# 110  POINT (69.17870 34.48792)  25114479                 0          C
# 111  POINT (65.73241 31.51364)  25114523                 0          C
# 112  POINT (68.85253 36.81209)  25114487                 0          C
# 113  POINT (70.46340 34.42453)  25114491                 0          C
# 114  POINT (69.61059 36.75049)  25114499                 0          C
#
#      overall_phase population_min population_percentage_min  \
# 0                3          22260                      0.20
# 1                3          38260                      0.20
# 2                3          33175                      0.25
# 3                3           1583                      0.20
# 4                3          14533                      0.20
# ..             ...            ...                       ...
# 110              3        2955890                       0.5
# 111              4         315875                      0.45
# 112              3         114547                      0.45
# 113              4         146338                       0.4
# 114              4          61674                      0.55
#
#                                          justification  prolonged_crisis  \
# 0                                                                  False
# 1                                                                  False
# 2                                                                  False
# 3                                                                  False
# 4                                                                  False
# ..                                                 ...               ...
# 110  The capital of the country was among the domai...             False
# 111  The province categorized as an extreme drought...             False
# 112  The current period 18.3 %of the households ado...             False
# 113  In Nangarhar urban  96% experienced shocks and...             False
# 114  Based on recent FSLA data, 64% of HHs in Takha...              True
#
#     population_phase_worse  ... phase3_estimated_population_projected  \
# 0                     None  ...                                111299
# 1                     None  ...                                191299
# 2                     None  ...                                132700
# 3                     None  ...                                  7911
# 4                     None  ...                                 72666
# ..                     ...  ...                                   ...
# 110                   None  ...                               5911781
# 111                   None  ...                                701944
# 112                   None  ...                                254549
# 113                   None  ...                                365844
# 114                   None  ...                                112133
#
#     phase3_estimated_population_projected2 phase3_population  \
# 0                                     None             16695
# 1                                     None             28695
# 2                                     None             26540
# 3                                     None              1187
# 4                                     None             10900
# ..                                     ...               ...
# 110                                   None           2069123
# 111                                   None            175486
# 112                                   None             76365
# 113                                   None             73169
# 114                                   None             39247
#
#     phase3_population_percentage  phase1_overall_phase  \
# 0                           0.15                     3
# 1                           0.15                     3
# 2                           0.20                     3
# 3                           0.15                     3
# 4                           0.15                     3
# ..                           ...                   ...
# 110                         0.35                     3
# 111                         0.25                     4
# 112                         0.30                     3
# 113                         0.20                     4
# 114                         0.35                     4
#
#     phase1_estimated_population_current phase1_estimated_population_projected  \
# 0                                111299                                111299
# 1                                191299                                191299
# 2                                132700                                132700
# 3                                  7911                                  7911
# 4                                 72666                                 72666
# ..                                  ...                                   ...
# 110                             5911781                               5911781
# 111                              701944                                701944
# 112                              254549                                254549
# 113                              365844                                365844
# 114                              112133                                112133
#
#      phase1_estimated_population_projected2 phase1_population  \
# 0                                      None             50085
# 1                                      None             86085
# 2                                      None             46445
# 3                                      None              2373
# 4                                      None             32700
# ..                                      ...               ...
# 110                                    None           1182356
# 111                                    None            140389
# 112                                    None             50910
# 113                                    None             73169
# 114                                    None             11213
#
#     phase1_population_percentage
# 0                           0.45
# 1                           0.45
# 2                           0.35
# 3                           0.30
# 4                           0.45
# ..                           ...
# 110                         0.20
# 111                         0.20
# 112                         0.20
# 113                         0.20
# 114                         0.10
#
# [115 rows x 47 columns]

# %%
all_points_gdf.explore()

# %%
# querying points in not geojson format to see if there is a difference in what is returned
all_points_json = get_ipc_data("points?format=json&type=A", "pd")
# make geodataframe from all_points["features"] geometry is in "coordinates"

all_points_json
# Out:
# <Response [200]>
#        aar_id  confidence_level ipc_period  overall_phase population_min  \
# 0    18724768                 0          C              3          22260
# 1    18724770                 0          C              3          38260
# 2    18724774                 0          C              3          33175
# 3    18724776                 0          C              3           1583
# 4    18724766                 0          C              3          14533
# ..        ...               ...        ...            ...            ...
# 110  25114479                 0          C              3        2955890
# 111  25114523                 0          C              4         315875
# 112  25114487                 0          C              3         114547
# 113  25114491                 0          C              4         146338
# 114  25114499                 0          C              4          61674
#
#     population_percentage_min  \
# 0                        0.20
# 1                        0.20
# 2                        0.25
# 3                        0.20
# 4                        0.20
# ..                        ...
# 110                       0.5
# 111                      0.45
# 112                      0.45
# 113                       0.4
# 114                      0.55
#
#                                          justification  prolonged_crisis  \
# 0                                                                  False
# 1                                                                  False
# 2                                                                  False
# 3                                                                  False
# 4                                                                  False
# ..                                                 ...               ...
# 110  The capital of the country was among the domai...             False
# 111  The province categorized as an extreme drought...             False
# 112  The current period 18.3 %of the households ado...             False
# 113  In Nangarhar urban  96% experienced shocks and...             False
# 114  Based on recent FSLA data, 64% of HHs in Takha...              True
#
#     population_phase_worse population_percentage_phase_worse    anl_id  \
# 0                     None                              None  18724686
# 1                     None                              None  18724686
# 2                     None                              None  18724686
# 3                     None                              None  18724686
# 4                     None                              None  18724686
# ..                     ...                               ...       ...
# 110                   None                              None  25114450
# 111                   None                              None  25114450
# 112                   None                              None  25114450
# 113                   None                              None  25114450
# 114                   None                              None  25114450
#
#                    title                                             phases  \
# 0             Mbale City  [{'overall_phase': 3, 'estimated_population_cu...
# 1    Mukono Municipality  [{'overall_phase': 3, 'estimated_population_cu...
# 2               Nakivale  [{'overall_phase': 3, 'estimated_population_cu...
# 3              Oruchinga  [{'overall_phase': 3, 'estimated_population_cu...
# 4              Rwamwanja  [{'overall_phase': 3, 'estimated_population_cu...
# ..                   ...                                                ...
# 110          Kabul Urban  [{'overall_phase': 3, 'estimated_population_cu...
# 111       Kandahar Urban  [{'overall_phase': 4, 'estimated_population_cu...
# 112         Kunduz Urban  [{'overall_phase': 3, 'estimated_population_cu...
# 113      Nangarhar Urban  [{'overall_phase': 4, 'estimated_population_cu...
# 114         Takhar Urban  [{'overall_phase': 4, 'estimated_population_cu...
#
#     icon  year country condition
# 0    urb  2020      UG         A
# 1    urb  2020      UG         A
# 2    idp  2020      UG         A
# 3    idp  2020      UG         A
# 4    idp  2020      UG         A
# ..   ...   ...     ...       ...
# 110  urb  2022      AF         A
# 111  urb  2022      AF         A
# 112  urb  2022      AF         A
# 113  urb  2022      AF         A
# 114  urb  2022      AF         A
#
# [115 rows x 17 columns]

# %%
all_population_df = get_ipc_data("areas?format=json", "pd")
all_population_df
# Out:
# <Response [200]>
#             id  estimated_population period      from        to    color  \
# 0     12133451               1546683      C  Dec 2015  Dec 2015  #9e9ac8
# 1     12133459                429949      C  Dec 2015  Dec 2015  #6a51a3
# 2     12133419                935466      C  Dec 2015  Dec 2015  #9e9ac8
# 3     12133421               2435730      C  Dec 2015  Dec 2015  #cbc9e2
# 4     12133423               3561343      C  Dec 2015  Dec 2015  #cbc9e2
# ...        ...                   ...    ...       ...       ...      ...
# 7939  26258593                340671      C  Jul 2022  Sep 2022  #FAE61E
# 7940  26258589                315943      C  Jul 2022  Sep 2022  #E67800
# 7941  26258597                133595      C  Jul 2022  Sep 2022  #E67800
# 7942  26258599                926976      C  Jul 2022  Sep 2022  #E67800
# 7943  26258601                781263      C  Jul 2022  Sep 2022  #E67800
#
#         anl_id       title  overall_phase  \
# 0     12133407    Bagerhat              3
# 1     12133407   Bandarban              4
# 2     12133407     Barguna              3
# 3     12133407     Barisal              2
# 4     12133407       Bogra              2
# ...        ...         ...            ...
# 7939  26258568       Taita              2
# 7940  26258568  TANA RIVER              3
# 7941  26258568     Tharaka              3
# 7942  26258568     Turkana              3
# 7943  26258568       Wajir              3
#
#                                                  phases country  year  \
# 0     [{'phase': 2, 'population': 510405, 'percent':...      BD  2015
# 1     [{'phase': 4, 'population': 85990, 'percent': ...      BD  2015
# 2     [{'phase': 3, 'population': 140320, 'percent':...      BD  2015
# 3     [{'phase': 4, 'population': 121787, 'percent':...      BD  2015
# 4     [{'phase': 1, 'population': 1780672, 'percent'...      BD  2015
# ...                                                 ...     ...   ...
# 7939  [{'phase': 1, 'population': 170336, 'percent':...      KE  2022
# 7940  [{'phase': 1, 'population': 31594, 'percent': ...      KE  2022
# 7941  [{'phase': 1, 'population': 46758, 'percent': ...      KE  2022
# 7942  [{'phase': 5, 'population': 0, 'percent': 0, '...      KE  2022
# 7943  [{'phase': 1, 'population': 78126, 'percent': ...      KE  2022
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 0            C                   417000                     0.26
# 1            C                   183000                     0.42
# 2            C                   187000                     0.20
# 3            C                   463000                     0.19
# 4            C                   623000                     0.17
# ...        ...                      ...                      ...
# 7939         A                        0                     0.00
# 7940         A                        0                     0.00
# 7941         A                        0                     0.00
# 7942         A                        0                     0.00
# 7943         A                        0                     0.00
#
# [7944 rows x 15 columns]

# %%
# checking to see if HFIC zones are the same as what is used IPC. This is a file I downloaded from here: https://fews.net/data
hfic_gdf = gpd.read_file("/Users/camkruse/Downloads/ALL_HFIC 2/ALL_HFIC/East Africa/EA_201812_CS.shp")

# %%
hfic_gdf.explore()

# %%
# print first row from all_areas_df
print (all_areas_df.iloc[3])
# Out:
# id                                                                  12135274
# estimated_population                                                 1171450
# period                                                                     C
# from                                                                Apr 2017
# to                                                                  May 2017
# color                                                                #FAE61E
# anl_id                                                              12135258
# title                                                        Crête congo nil
# overall_phase                                                              2
# phases                     [{'phase': 4, 'population': 58573, 'percent': ...
# country                                                                   BI
# year                                                                    2017
# condition                                                                  A
# phase3_worse_population                                               222575
# phase3_worse_percentage                                                 0.19
# Name: 3, dtype: object

# %%
# read in fewsnet world admin data from /Users/camkruse/Downloads/FEWSNET_World_Admin/FEWSNET_Admin2.shp
fewsnetadmin_gdf = gpd.read_file("/Users/camkruse/Downloads/FEWSNET_World_Admin/FEWSNET_Admin2.shp")
# fewsnetadmin_gdf.explore()

# %%
fewsnetadmin_gdf
# Out:
#               FNID  EFF_YEAR COUNTRY       ADMIN0        ADMIN1 ADMIN1FR  \
# 0     AO2008A21701      2008      AO       Angola          Uige     None
# 1     AO2008A21501      2008      AO       Angola        Moxico     None
# 2     AO2008A20901      2008      AO       Angola  Kuanza Norte     None
# 3     AO2008A21001      2008      AO       Angola    Kuanza Sul     None
# 4     AO2008A20101      2008      AO       Angola         Bengo     None
# ...            ...       ...     ...          ...           ...      ...
# 6560  AF2017A20105      2017      AF  Afghanistan         Kabul     None
# 6561  AF2017A20907      2017      AF  Afghanistan       Baghlan     None
# 6562  AF2017A21713      2017      AF  Afghanistan    Badakhshan     None
# 6563  AF2017A20102      2017      AF  Afghanistan         Kabul     None
# 6564  AF2017A21816      2017      AF  Afghanistan        Takhar     None
#
#      ADMIN1SP      ADMIN1PT          ADMIN2 ADMIN2FR ADMIN2SP      ADMIN2PT  \
# 0        None          Uige      Alto Cuale     None     None    Alto Cuale
# 1        None        Moxico    Alto Zambeze     None     None  Alto Zambeze
# 2        None  Kuanza Norte          Ambaca     None     None        Ambaca
# 3        None    Kuanza Sul          Amboim     None     None        Amboim
# 4        None         Bengo          Ambriz     None     None        Ambriz
# ...       ...           ...             ...      ...      ...           ...
# 6560     None          None        Deh Sabz     None     None          None
# 6561     None          None         Andarab     None     None          None
# 6562     None          None  Shahr-e-Buzorg     None     None          None
# 6563     None          None         Paghman     None     None          None
# 6564     None          None         Chah Ab     None     None          None
#
#                                             ALIASES  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 6560                ~Dehsabz~Deh-e-Sabz~Deh-e Sabz~
# 6561                                           None
# 6562  ~Shahr-e Buzurg~Shahri Buzurg~Shahr-e Buzurg~
# 6563                                           None
# 6564                                           None
#
#                                                geometry
# 0     POLYGON ((16.34542 -7.47550, 16.34498 -7.47693...
# 1     POLYGON ((24.01645 -11.01787, 24.01387 -11.030...
# 2     POLYGON ((15.69911 -8.01768, 15.70128 -8.01780...
# 3     POLYGON ((14.51918 -10.76831, 14.52180 -10.770...
# 4     POLYGON ((13.81469 -7.66262, 13.81628 -7.66297...
# ...                                                 ...
# 6560  POLYGON ((69.46155 34.58448, 69.46121 34.58369...
# 6561  POLYGON ((69.04545 35.81928, 69.04450 35.81818...
# 6562  POLYGON ((70.06893 37.38423, 70.07026 37.38434...
# 6563  POLYGON ((69.03724 34.59171, 69.03838 34.59173...
# 6564  POLYGON ((69.95131 37.56805, 69.95389 37.56398...
#
# [6565 rows x 14 columns]

# %%
# check if "Chongwe" exists in fewsnetadmin_gdf
fewsnetadmin_gdf[fewsnetadmin_gdf["ADMIN2"] == "Chongwe"]
# Out:
#              FNID  EFF_YEAR COUNTRY  ADMIN0  ADMIN1 ADMIN1FR ADMIN1SP  \
# 377  ZM2012A20503      2012      ZM  Zambia  Lusaka     None     None
#
#     ADMIN1PT   ADMIN2 ADMIN2FR ADMIN2SP ADMIN2PT ALIASES  \
# 377     None  Chongwe     None     None     None    None
#
#                                               geometry
# 377  POLYGON ((28.80332 -15.16446, 28.80416 -15.165...

# %%
# print rows from all_areas_df where title is "Chongwe"
all_areas_df[all_areas_df["title"] == "Chongwe"]
# Out:
#             id  estimated_population period      from        to    color  \
# 1050  12851908                183368      C  May 2018  Sep 2018  #FAE61E
# 2200  13599739                171409      C  May 2019  Sep 2019  #FAE61E
# 7457  26097138                204279      C  Jun 2022  Sep 2022  #FAE61E
#
#         anl_id    title  overall_phase  \
# 1050  12851889  Chongwe              2
# 2200  13599687  Chongwe              2
# 7457  26096991  Chongwe              2
#
#                                                  phases country  year  \
# 1050  [{'phase': 4, 'population': 5501, 'percent': 0...      ZM  2018
# 2200  [{'phase': 4, 'population': 0, 'percent': 0, '...      ZM  2019
# 7457  [{'phase': 1, 'population': 91926, 'percent': ...      ZM  2022
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 1050         A                    27505                     0.16
# 2200         A                    25711                     0.15
# 7457         A                        0                     0.00

# %%
# print rows from all_areas who's title does not have a match in fewnetadmin_gdf
all_areas_df[~all_areas_df["title"].isin(fewsnetadmin_gdf["ADMIN2"])]
# Out:
#             id  estimated_population period      from        to    color  \
# 0     12135272                906391      C  Apr 2017  May 2017  #E67800
# 1     12135266               1772906      C  Apr 2017  May 2017  #E67800
# 2     12135264                238111      C  Apr 2017  May 2017  #E67800
# 3     12135274               1171450      C  Apr 2017  May 2017  #FAE61E
# 4     12135260                651193      C  Apr 2017  May 2017  #C80000
# ...        ...                   ...    ...       ...       ...      ...
# 7591  26258587                310327      C  Jul 2022  Sep 2022  #E67800
# 7592  26258593                340671      C  Jul 2022  Sep 2022  #FAE61E
# 7593  26258589                315943      C  Jul 2022  Sep 2022  #E67800
# 7595  26258599                926976      C  Jul 2022  Sep 2022  #E67800
# 7596  26258601                781263      C  Jul 2022  Sep 2022  #E67800
#
#         anl_id                   title  overall_phase  \
# 0     12135258    Dépressions de l`est              3
# 1     12135258  Plateaux secs de l`est              3
# 2     12135258                Buragane              3
# 3     12135258         Crête congo nil              2
# 4     12135258     Dépressions du nord              4
# ...        ...                     ...            ...
# 7591  26258568                 Samburu              3
# 7592  26258568                   Taita              2
# 7593  26258568              TANA RIVER              3
# 7595  26258568                 Turkana              3
# 7596  26258568                   Wajir              3
#
#                                                  phases country  year  \
# 0     [{'phase': 1, 'population': 271917, 'percent':...      BI  2017
# 1     [{'phase': 1, 'population': 354581, 'percent':...      BI  2017
# 2     [{'phase': 2, 'population': 83339, 'percent': ...      BI  2017
# 3     [{'phase': 4, 'population': 58573, 'percent': ...      BI  2017
# 4     [{'phase': 4, 'population': 130239, 'percent':...      BI  2017
# ...                                                 ...     ...   ...
# 7591  [{'phase': 1, 'population': 46549, 'percent': ...      KE  2022
# 7592  [{'phase': 1, 'population': 170336, 'percent':...      KE  2022
# 7593  [{'phase': 1, 'population': 31594, 'percent': ...      KE  2022
# 7595  [{'phase': 5, 'population': 0, 'percent': 0, '...      KE  2022
# 7596  [{'phase': 1, 'population': 78126, 'percent': ...      KE  2022
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 0            A                   271918                     0.30
# 1            A                   709163                     0.40
# 2            A                    47623                     0.20
# 3            A                   222575                     0.19
# 4            A                   293037                     0.45
# ...        ...                      ...                      ...
# 7591         A                        0                     0.00
# 7592         A                        0                     0.00
# 7593         A                        0                     0.00
# 7595         A                        0                     0.00
# 7596         A                        0                     0.00
#
# [4180 rows x 15 columns]

# %% [markdown]
# ## Trying to make a heatmap with IPC Areas data

# %%
all_areas_json = get_ipc_data("areas?format=json&type=A", "json")
all_areas_json
# Out:
# <Response [200]>
# [{'id': '12135272',
#   'estimated_population': 906391,
#   'period': 'C',
#   'from': 'Apr 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135258',
#   'title': 'Dépressions de l`est',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 271917,
#     'percent': 0.3,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 362556, 'percent': 0.4, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 226598, 'percent': 0.25, 'color': '#E67800'},
#    {'phase': 4, 'population': 45320, 'percent': 0.05, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'BI',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 271918,
#   'phase3_worse_percentage': 0.3},
#  {'id': '12135266',
#   'estimated_population': 1772906,
#   'period': 'C',
#   'from': 'Apr 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135258',
#   'title': 'Plateaux secs de l`est',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 354581,
#     'percent': 0.2,
#     'color': '#CDFACD'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 177291, 'percent': 0.1, 'color': '#C80000'},
#    {'phase': 3, 'population': 531872, 'percent': 0.3, 'color': '#E67800'},
#    {'phase': 2, 'population': 709162, 'percent': 0.4, 'color': '#FAE61E'}],
#   'country': 'BI',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 709163,
#   'phase3_worse_percentage': 0.4},
#  {'id': '12135264',
#   'estimated_population': 238111,
#   'period': 'C',
#   'from': 'Apr 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135258',
#   'title': 'Buragane',
#   'overall_phase': 3,
#   'phases': [{'phase': 2,
#     'population': 83339,
#     'percent': 0.35,
#     'color': '#FAE61E'},
#    {'phase': 3, 'population': 35717, 'percent': 0.15, 'color': '#E67800'},
#    {'phase': 4, 'population': 11906, 'percent': 0.05, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 107150, 'percent': 0.45, 'color': '#CDFACD'}],
#   'country': 'BI',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 47623,
#   'phase3_worse_percentage': 0.2},
#  {'id': '12135274',
#   'estimated_population': 1171450,
#   'period': 'C',
#   'from': 'Apr 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135258',
#   'title': 'Crête congo nil',
#   'overall_phase': 2,
#   'phases': [{'phase': 4,
#     'population': 58573,
#     'percent': 0.05,
#     'color': '#C80000'},
#    {'phase': 3, 'population': 164003, 'percent': 0.14, 'color': '#E67800'},
#    {'phase': 2, 'population': 538867, 'percent': 0.46, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 410008, 'percent': 0.35, 'color': '#CDFACD'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'BI',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 222575,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12135260',
#   'estimated_population': 651193,
#   'period': 'C',
#   'from': 'Apr 2017',
#   'to': 'May 2017',
#   'color': '#C80000',
#   'anl_id': '12135258',
#   'title': 'Dépressions du nord',
#   'overall_phase': 4,
#   'phases': [{'phase': 4,
#     'population': 130239,
#     'percent': 0.2,
#     'color': '#C80000'},
#    {'phase': 3, 'population': 162798, 'percent': 0.25, 'color': '#E67800'},
#    {'phase': 2, 'population': 195358, 'percent': 0.3, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 162798, 'percent': 0.25, 'color': '#CDFACD'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'BI',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 293037,
#   'phase3_worse_percentage': 0.45},
#  {'id': '12135270',
#   'estimated_population': 1344463,
#   'period': 'C',
#   'from': 'Apr 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135258',
#   'title': 'Haute altitude',
#   'overall_phase': 2,
#   'phases': [{'phase': 2,
#     'population': 537785,
#     'percent': 0.4,
#     'color': '#FAE61E'},
#    {'phase': 3, 'population': 174780, 'percent': 0.13, 'color': '#E67800'},
#    {'phase': 4, 'population': 26889, 'percent': 0.02, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 605008, 'percent': 0.45, 'color': '#CDFACD'}],
#   'country': 'BI',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 201669,
#   'phase3_worse_percentage': 0.15},
#  {'id': '12135268',
#   'estimated_population': 760985,
#   'period': 'C',
#   'from': 'Apr 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135258',
#   'title': 'Imbo',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 228296,
#     'percent': 0.3,
#     'color': '#CDFACD'},
#    {'phase': 4, 'population': 76099, 'percent': 0.1, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 2, 'population': 266345, 'percent': 0.35, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 190246, 'percent': 0.25, 'color': '#E67800'}],
#   'country': 'BI',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 266344,
#   'phase3_worse_percentage': 0.35},
#  {'id': '12135262',
#   'estimated_population': 2913365,
#   'period': 'C',
#   'from': 'Apr 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135258',
#   'title': 'Plateaux humides',
#   'overall_phase': 2,
#   'phases': [{'phase': 2,
#     'population': 1340148,
#     'percent': 0.46,
#     'color': '#FAE61E'},
#    {'phase': 1, 'population': 1019678, 'percent': 0.35, 'color': '#CDFACD'},
#    {'phase': 3, 'population': 378737, 'percent': 0.13, 'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 174802, 'percent': 0.06, 'color': '#C80000'}],
#   'country': 'BI',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 553539,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12135633',
#   'estimated_population': 50264,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135625',
#   'title': 'Bamingui-bangoran',
#   'overall_phase': 3,
#   'phases': [{'phase': 3,
#     'population': 14577,
#     'percent': 0.29,
#     'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 4524, 'percent': 0.09, 'color': '#C80000'},
#    {'phase': 1, 'population': 10053, 'percent': 0.2, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 20106, 'percent': 0.4, 'color': '#FAE61E'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 20105,
#   'phase3_worse_percentage': 0.38},
#  {'id': '12135638',
#   'estimated_population': 289696,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135625',
#   'title': 'Basse-kotto',
#   'overall_phase': 3,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 3, 'population': 55042, 'percent': 0.19, 'color': '#E67800'},
#    {'phase': 2, 'population': 112981, 'percent': 0.39, 'color': '#FAE61E'},
#    {'phase': 4, 'population': 40557, 'percent': 0.14, 'color': '#C80000'},
#    {'phase': 1, 'population': 72424, 'percent': 0.25, 'color': '#CDFACD'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 101393,
#   'phase3_worse_percentage': 0.33},
#  {'id': '12135635',
#   'estimated_population': 66976,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135625',
#   'title': 'Haute-kotto',
#   'overall_phase': 3,
#   'phases': [{'phase': 3,
#     'population': 16744,
#     'percent': 0.25,
#     'color': '#E67800'},
#    {'phase': 1, 'population': 12725, 'percent': 0.19, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 26121, 'percent': 0.39, 'color': '#FAE61E'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 9377, 'percent': 0.14, 'color': '#C80000'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 26790,
#   'phase3_worse_percentage': 0.39},
#  {'id': '12135640',
#   'estimated_population': 105013,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135625',
#   'title': 'Haut-mbomou',
#   'overall_phase': 3,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 9451, 'percent': 0.09, 'color': '#C80000'},
#    {'phase': 3, 'population': 25203, 'percent': 0.24, 'color': '#E67800'},
#    {'phase': 2, 'population': 40955, 'percent': 0.39, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 25203, 'percent': 0.24, 'color': '#CDFACD'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 36754,
#   'phase3_worse_percentage': 0.33},
#  {'id': '12135645',
#   'estimated_population': 137690,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135625',
#   'title': 'Kémo',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 13769,
#     'percent': 0.1,
#     'color': '#E67800'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 2, 'population': 68845, 'percent': 0.5, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 55076, 'percent': 0.4, 'color': '#CDFACD'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 13769,
#   'phase3_worse_percentage': 0.1},
#  {'id': '12135652',
#   'estimated_population': 287051,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135625',
#   'title': 'Lobaye',
#   'overall_phase': 2,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 3, 'population': 43058, 'percent': 0.15, 'color': '#E67800'},
#    {'phase': 2, 'population': 172231, 'percent': 0.6, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 71763, 'percent': 0.25, 'color': '#CDFACD'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 43058,
#   'phase3_worse_percentage': 0.15},
#  {'id': '12135666',
#   'estimated_population': 424160,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135625',
#   'title': 'Mambéré-kadéï',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 42416,
#     'percent': 0.1,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 212080, 'percent': 0.5, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 148456, 'percent': 0.35, 'color': '#CDFACD'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 16966, 'percent': 0.04, 'color': '#C80000'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 63622,
#   'phase3_worse_percentage': 0.14},
#  {'id': '12135642',
#   'estimated_population': 190700,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135625',
#   'title': 'Mbomou',
#   'overall_phase': 2,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 3, 'population': 28605, 'percent': 0.15, 'color': '#E67800'},
#    {'phase': 2, 'population': 95350, 'percent': 0.5, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 66745, 'percent': 0.35, 'color': '#CDFACD'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 28605,
#   'phase3_worse_percentage': 0.15},
#  {'id': '12135647',
#   'estimated_population': 0,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#ffffff',
#   'anl_id': '12135625',
#   'title': 'Nana-gribizi',
#   'overall_phase': 0,
#   'phases': [{'phase': 1, 'population': 0, 'percent': 0, 'color': '#CDFACD'},
#    {'phase': 3, 'population': 0, 'percent': 0, 'color': '#E67800'},
#    {'phase': 2, 'population': 0, 'percent': 0, 'color': '#FAE61E'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 0,
#   'phase3_worse_percentage': 0},
#  {'id': '12135628',
#   'estimated_population': 271692,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135625',
#   'title': 'Nana-mambéré',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 92375,
#     'percent': 0.34,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 135846, 'percent': 0.5, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 24452, 'percent': 0.09, 'color': '#E67800'},
#    {'phase': 4, 'population': 13585, 'percent': 0.05, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 40754,
#   'phase3_worse_percentage': 0.14},
#  {'id': '12135654',
#   'estimated_population': 414776,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135625',
#   'title': "Ombella m'poko",
#   'overall_phase': 2,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 161763, 'percent': 0.39, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 182501, 'percent': 0.44, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 58069, 'percent': 0.14, 'color': '#E67800'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 62216,
#   'phase3_worse_percentage': 0.14},
#  {'id': '12135649',
#   'estimated_population': 321739,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135625',
#   'title': 'Ouaka',
#   'overall_phase': 3,
#   'phases': [{'phase': 2,
#     'population': 106174,
#     'percent': 0.33,
#     'color': '#FAE61E'},
#    {'phase': 3, 'population': 35391, 'percent': 0.11, 'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 48261, 'percent': 0.15, 'color': '#C80000'},
#    {'phase': 1, 'population': 64348, 'percent': 0.2, 'color': '#CDFACD'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 148000,
#   'phase3_worse_percentage': 0.26},
#  {'id': '12135657',
#   'estimated_population': 429303,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135625',
#   'title': 'Ouham',
#   'overall_phase': 3,
#   'phases': [{'phase': 3,
#     'population': 128791,
#     'percent': 0.3,
#     'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 107326, 'percent': 0.25, 'color': '#CDFACD'},
#    {'phase': 4, 'population': 60102, 'percent': 0.14, 'color': '#C80000'},
#    {'phase': 2, 'population': 128791, 'percent': 0.3, 'color': '#FAE61E'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 193186,
#   'phase3_worse_percentage': 0.44},
#  {'id': '12135659',
#   'estimated_population': 500564,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135625',
#   'title': 'Ouham pendé',
#   'overall_phase': 3,
#   'phases': [{'phase': 3,
#     'population': 200226,
#     'percent': 0.4,
#     'color': '#E67800'},
#    {'phase': 4, 'population': 90102, 'percent': 0.18, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 2, 'population': 105118, 'percent': 0.21, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 100113, 'percent': 0.2, 'color': '#CDFACD'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 290328,
#   'phase3_worse_percentage': 0.58},
#  {'id': '12135630',
#   'estimated_population': 117523,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12135625',
#   'title': 'Sangha-mbaéré',
#   'overall_phase': 2,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 3, 'population': 14103, 'percent': 0.12, 'color': '#E67800'},
#    {'phase': 1, 'population': 23505, 'percent': 0.2, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 79916, 'percent': 0.68, 'color': '#FAE61E'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 14103,
#   'phase3_worse_percentage': 0.12},
#  {'id': '12135664',
#   'estimated_population': 60759,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12135625',
#   'title': 'Vakaga',
#   'overall_phase': 3,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 6076, 'percent': 0.1, 'color': '#C80000'},
#    {'phase': 3, 'population': 21266, 'percent': 0.35, 'color': '#E67800'},
#    {'phase': 1, 'population': 18228, 'percent': 0.3, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 15190, 'percent': 0.25, 'color': '#FAE61E'}],
#   'country': 'CF',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 27342,
#   'phase3_worse_percentage': 0.45},
#  {'id': '12138315',
#   'estimated_population': 426000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Jul 2017',
#   'color': '#FAE61E',
#   'anl_id': '12138309',
#   'title': 'Chiquimula',
#   'overall_phase': 2,
#   'phases': [{'phase': 2,
#     'population': 63900,
#     'percent': 0.15,
#     'color': '#FAE61E'},
#    {'phase': 1, 'population': 315240, 'percent': 0.74, 'color': '#CDFACD'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 3, 'population': 42600, 'percent': 0.1, 'color': '#E67800'}],
#   'country': 'GT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 43000,
#   'phase3_worse_percentage': 0.1},
#  {'id': '12138319',
#   'estimated_population': 1300000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Jul 2017',
#   'color': '#FAE61E',
#   'anl_id': '12138309',
#   'title': 'Huehuetenango',
#   'overall_phase': 2,
#   'phases': [{'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 1, 'population': 858000, 'percent': 0.66, 'color': '#CDFACD'},
#    {'phase': 3, 'population': 130000, 'percent': 0.1, 'color': '#E67800'},
#    {'phase': 2, 'population': 325000, 'percent': 0.25, 'color': '#FAE61E'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'GT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 132000,
#   'phase3_worse_percentage': 0.1},
#  {'id': '12138313',
#   'estimated_population': 1200000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Jul 2017',
#   'color': '#FAE61E',
#   'anl_id': '12138309',
#   'title': 'Quiche',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 804000,
#     'percent': 0.67,
#     'color': '#CDFACD'},
#    {'phase': 3, 'population': 168000, 'percent': 0.14, 'color': '#E67800'},
#    {'phase': 2, 'population': 168000, 'percent': 0.14, 'color': '#FAE61E'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'}],
#   'country': 'GT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 174000,
#   'phase3_worse_percentage': 0.14},
#  {'id': '12138311',
#   'estimated_population': 1200000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Jul 2017',
#   'color': '#FAE61E',
#   'anl_id': '12138309',
#   'title': 'San Marcos',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 516000,
#     'percent': 0.43,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 552000, 'percent': 0.46, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 84000, 'percent': 0.07, 'color': '#E67800'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'GT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 94000,
#   'phase3_worse_percentage': 0.07},
#  {'id': '12138317',
#   'estimated_population': 527000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Jul 2017',
#   'color': '#FAE61E',
#   'anl_id': '12138309',
#   'title': 'Totonicapan',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 347820,
#     'percent': 0.66,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 142290, 'percent': 0.27, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 21080, 'percent': 0.04, 'color': '#E67800'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'GT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 26000,
#   'phase3_worse_percentage': 0.04},
#  {'id': '12140926',
#   'estimated_population': 458065,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Artibonite ht04',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 98942,
#     'percent': 0.22,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 270258, 'percent': 0.59, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 64129, 'percent': 0.14, 'color': '#E67800'},
#    {'phase': 4, 'population': 24736, 'percent': 0.05, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 88865,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12140970',
#   'estimated_population': 707601,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Centre ht03',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 151955,
#     'percent': 0.21,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 257168, 'percent': 0.36, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 206011, 'percent': 0.29, 'color': '#E67800'},
#    {'phase': 4, 'population': 92467, 'percent': 0.13, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 298478,
#   'phase3_worse_percentage': 0.42},
#  {'id': '12140985',
#   'estimated_population': 153652,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Grande-anse ht07',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 34731,
#     'percent': 0.22,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 58038, 'percent': 0.38, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 41077, 'percent': 0.27, 'color': '#E67800'},
#    {'phase': 4, 'population': 19807, 'percent': 0.13, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 60884,
#   'phase3_worse_percentage': 0.4},
#  {'id': '12140944',
#   'estimated_population': 267852,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Grande-anse ht08',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 48723,
#     'percent': 0.18,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 105877, 'percent': 0.4, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 65676, 'percent': 0.25, 'color': '#E67800'},
#    {'phase': 4, 'population': 47576, 'percent': 0.18, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 113252,
#   'phase3_worse_percentage': 0.43},
#  {'id': '12140946',
#   'estimated_population': 798141,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Nord ht02',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 223479,
#     'percent': 0.28,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 375126, 'percent': 0.47, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 151646, 'percent': 0.19, 'color': '#E67800'},
#    {'phase': 4, 'population': 47888, 'percent': 0.06, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 199534,
#   'phase3_worse_percentage': 0.25},
#  {'id': '12140923',
#   'estimated_population': 157903,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Nippes ht01',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 40110,
#     'percent': 0.26,
#     'color': '#CDFACD'},
#    {'phase': 3, 'population': 26812, 'percent': 0.17, 'color': '#E67800'},
#    {'phase': 4, 'population': 26325, 'percent': 0.17, 'color': '#C80000'},
#    {'phase': 2, 'population': 64656, 'percent': 0.41, 'color': '#FAE61E'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 53137,
#   'phase3_worse_percentage': 0.34},
#  {'id': '12140935',
#   'estimated_population': 167769,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Nippes ht07',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 26675,
#     'percent': 0.15,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 57880, 'percent': 0.34, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 66347, 'percent': 0.39, 'color': '#E67800'},
#    {'phase': 4, 'population': 16777, 'percent': 0.1, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 83124,
#   'phase3_worse_percentage': 0.49},
#  {'id': '12140979',
#   'estimated_population': 367038,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Nord-est ht02',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 57258,
#     'percent': 0.16,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 225728, 'percent': 0.61, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 50651, 'percent': 0.14, 'color': '#E67800'},
#    {'phase': 4, 'population': 33400, 'percent': 0.09, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 84051,
#   'phase3_worse_percentage': 0.23},
#  {'id': '12140964',
#   'estimated_population': 330098,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Nord-ouest ht01',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 20514,
#     'percent': 0.06,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 102120, 'percent': 0.31, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 162164, 'percent': 0.49, 'color': '#E67800'},
#    {'phase': 4, 'population': 45300, 'percent': 0.14, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 207464,
#   'phase3_worse_percentage': 0.63},
#  {'id': '12140952',
#   'estimated_population': 277489,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Nord-ouest ht02',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 63942,
#     'percent': 0.23,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 98707, 'percent': 0.35, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 85439, 'percent': 0.31, 'color': '#E67800'},
#    {'phase': 4, 'population': 29401, 'percent': 0.11, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 114840,
#   'phase3_worse_percentage': 0.42},
#  {'id': '12140961',
#   'estimated_population': 264325,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Ouest ht05',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 107427,
#     'percent': 0.4,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 124375, 'percent': 0.47, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 13707, 'percent': 0.05, 'color': '#E67800'},
#    {'phase': 4, 'population': 18815, 'percent': 0.07, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 32522,
#   'phase3_worse_percentage': 0.12},
#  {'id': '12140988',
#   'estimated_population': 120156,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Ouest ht06',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 34725,
#     'percent': 0.29,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 62121, 'percent': 0.52, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 16822, 'percent': 0.14, 'color': '#E67800'},
#    {'phase': 4, 'population': 6488, 'percent': 0.05, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 23310,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12140920',
#   'estimated_population': 1005027,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Ouest ht07',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 313398,
#     'percent': 0.26,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 504803, 'percent': 0.5, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 100511, 'percent': 0.1, 'color': '#E67800'},
#    {'phase': 4, 'population': 86315, 'percent': 0.09, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 186826,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12140973',
#   'estimated_population': 94602,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Sud ht01',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 19488,
#     'percent': 0.2,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 55721, 'percent': 0.59, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 8514, 'percent': 0.09, 'color': '#E67800'},
#    {'phase': 4, 'population': 10879, 'percent': 0.11, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 19393,
#   'phase3_worse_percentage': 0.2},
#  {'id': '12140929',
#   'estimated_population': 366109,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Sud ht07',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 80771,
#     'percent': 0.22,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 143555, 'percent': 0.39, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 121936, 'percent': 0.33, 'color': '#E67800'},
#    {'phase': 4, 'population': 19847, 'percent': 0.05, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 141783,
#   'phase3_worse_percentage': 0.38},
#  {'id': '12140932',
#   'estimated_population': 226223,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Sud ht08',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 58545,
#     'percent': 0.26,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 87954, 'percent': 0.38, 'color': '#FAE61E'},
#    {'phase': 4, 'population': 18946, 'percent': 0.08, 'color': '#C80000'},
#    {'phase': 3, 'population': 60778, 'percent': 0.27, 'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 79724,
#   'phase3_worse_percentage': 0.35},
#  {'id': '12140949',
#   'estimated_population': 370071,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Sud-est ht01',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 106197,
#     'percent': 0.28,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 142991, 'percent': 0.38, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 92963, 'percent': 0.25, 'color': '#E67800'},
#    {'phase': 4, 'population': 27921, 'percent': 0.07, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 120884,
#   'phase3_worse_percentage': 0.32},
#  {'id': '12140976',
#   'estimated_population': 42388,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Ville de jérémie',
#   'overall_phase': 2,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 15490, 'percent': 0.36, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 21541, 'percent': 0.43, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 4968, 'percent': 0.12, 'color': '#E67800'},
#    {'phase': 4, 'population': 390, 'percent': 0.01, 'color': '#C80000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 5358,
#   'phase3_worse_percentage': 0.13},
#  {'id': '12140958',
#   'estimated_population': 86780,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#FAE61E',
#   'anl_id': '12140917',
#   'title': 'Ville des cayes',
#   'overall_phase': 2,
#   'phases': [{'phase': 1,
#     'population': 42338,
#     'percent': 0.49,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 41672, 'percent': 0.48, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 2770, 'percent': 0.03, 'color': '#E67800'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 2770,
#   'phase3_worse_percentage': 0.03},
#  {'id': '12140938',
#   'estimated_population': 213716,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Sud-est ht07',
#   'overall_phase': 3,
#   'phases': [{'phase': 4,
#     'population': 12767,
#     'percent': 0.05,
#     'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 57044, 'percent': 0.26, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 102486, 'percent': 0.47, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 41419, 'percent': 0.19, 'color': '#E67800'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 54186,
#   'phase3_worse_percentage': 0.24},
#  {'id': '12140955',
#   'estimated_population': 401532,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'Artibonite ht03',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 58832,
#     'percent': 0.15,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 237671, 'percent': 0.59, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 79213, 'percent': 0.2, 'color': '#E67800'},
#    {'phase': 4, 'population': 25816, 'percent': 0.06, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 105029,
#   'phase3_worse_percentage': 0.26},
#  {'id': '12140941',
#   'estimated_population': 678576,
#   'period': 'C',
#   'from': 'Feb 2017',
#   'to': 'May 2017',
#   'color': '#E67800',
#   'anl_id': '12140917',
#   'title': 'La gonave & artibon ht01',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 71962,
#     'percent': 0.11,
#     'color': '#CDFACD'},
#    {'phase': 2, 'population': 331689, 'percent': 0.49, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 224893, 'percent': 0.33, 'color': '#E67800'},
#    {'phase': 4, 'population': 50031, 'percent': 0.07, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 274924,
#   'phase3_worse_percentage': 0.4},
#  {'id': '12144733',
#   'estimated_population': 249000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Sep 2017',
#   'color': '#CDFACD',
#   'anl_id': '12144729',
#   'title': 'Hhohho',
#   'overall_phase': 1,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 224100, 'percent': 0.9, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 12450, 'percent': 0.05, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 12450, 'percent': 0.05, 'color': '#E67800'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'}],
#   'country': 'SZ',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 12450,
#   'phase3_worse_percentage': 0.05},
#  {'id': '12144735',
#   'estimated_population': 197000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Sep 2017',
#   'color': '#E67800',
#   'anl_id': '12144729',
#   'title': 'Lubombo',
#   'overall_phase': 3,
#   'phases': [{'phase': 2,
#     'population': 39400,
#     'percent': 0.2,
#     'color': '#FAE61E'},
#    {'phase': 3, 'population': 39400, 'percent': 0.2, 'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 108350, 'percent': 0.55, 'color': '#CDFACD'},
#    {'phase': 4, 'population': 9850, 'percent': 0.05, 'color': '#C80000'}],
#   'country': 'SZ',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 49250,
#   'phase3_worse_percentage': 0.25},
#  {'id': '12144731',
#   'estimated_population': 264000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Sep 2017',
#   'color': '#FAE61E',
#   'anl_id': '12144729',
#   'title': 'Manzini',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 26400,
#     'percent': 0.1,
#     'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 2, 'population': 34320, 'percent': 0.13, 'color': '#FAE61E'},
#    {'phase': 4, 'population': 5280, 'percent': 0.02, 'color': '#C80000'},
#    {'phase': 1, 'population': 198000, 'percent': 0.75, 'color': '#CDFACD'}],
#   'country': 'SZ',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 31680,
#   'phase3_worse_percentage': 0.12},
#  {'id': '12144737',
#   'estimated_population': 200000,
#   'period': 'C',
#   'from': 'Jul 2017',
#   'to': 'Sep 2017',
#   'color': '#E67800',
#   'anl_id': '12144729',
#   'title': 'Shiselweni',
#   'overall_phase': 3,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 2, 'population': 40000, 'percent': 0.2, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 40000, 'percent': 0.2, 'color': '#E67800'},
#    {'phase': 4, 'population': 4000, 'percent': 0.02, 'color': '#C80000'},
#    {'phase': 1, 'population': 116000, 'percent': 0.58, 'color': '#CDFACD'}],
#   'country': 'SZ',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 44000,
#   'phase3_worse_percentage': 0.22},
#  {'id': '12148901',
#   'estimated_population': 0,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#ffffff',
#   'anl_id': '12148833',
#   'title': 'Ville de jérémie',
#   'overall_phase': 0,
#   'phases': [{'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 3, 'population': 0, 'percent': 0, 'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 0, 'percent': 0, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 0, 'percent': 0, 'color': '#FAE61E'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 0,
#   'phase3_worse_percentage': 0},
#  {'id': '12148866',
#   'estimated_population': 0,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#ffffff',
#   'anl_id': '12148833',
#   'title': 'Ville des cayes',
#   'overall_phase': 0,
#   'phases': [{'phase': 3, 'population': 0, 'percent': 0, 'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 0, 'percent': 0, 'color': '#CDFACD'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 2, 'population': 0, 'percent': 0, 'color': '#FAE61E'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 0,
#   'phase3_worse_percentage': 0},
#  {'id': '12148868',
#   'estimated_population': 798141,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#FAE61E',
#   'anl_id': '12148833',
#   'title': 'Nord ht02',
#   'overall_phase': 2,
#   'phases': [{'phase': 2,
#     'population': 375126,
#     'percent': 0.47,
#     'color': '#FAE61E'},
#    {'phase': 3, 'population': 151647, 'percent': 0.19, 'color': '#E67800'},
#    {'phase': 1, 'population': 263387, 'percent': 0.33, 'color': '#CDFACD'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 152531,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12148851',
#   'estimated_population': 458065,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#FAE61E',
#   'anl_id': '12148833',
#   'title': 'Artibonite ht04',
#   'overall_phase': 2,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 146581, 'percent': 0.32, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 233613, 'percent': 0.51, 'color': '#FAE61E'},
#    {'phase': 4, 'population': 4581, 'percent': 0.01, 'color': '#C80000'},
#    {'phase': 3, 'population': 68710, 'percent': 0.15, 'color': '#E67800'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 76345,
#   'phase3_worse_percentage': 0.16},
#  {'id': '12148854',
#   'estimated_population': 707601,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#FAE61E',
#   'anl_id': '12148833',
#   'title': 'Centre ht03',
#   'overall_phase': 2,
#   'phases': [{'phase': 4,
#     'population': 21228,
#     'percent': 0.03,
#     'color': '#C80000'},
#    {'phase': 2, 'population': 304268, 'percent': 0.43, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 247660, 'percent': 0.35, 'color': '#CDFACD'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 3, 'population': 113216, 'percent': 0.16, 'color': '#E67800'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 147080,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12148845',
#   'estimated_population': 153652,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#E67800',
#   'anl_id': '12148833',
#   'title': 'Grande-anse ht07',
#   'overall_phase': 3,
#   'phases': [{'phase': 1,
#     'population': 56851,
#     'percent': 0.37,
#     'color': '#CDFACD'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 2, 'population': 49169, 'percent': 0.32, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 32267, 'percent': 0.21, 'color': '#E67800'},
#    {'phase': 4, 'population': 10756, 'percent': 0.07, 'color': '#C80000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 45518,
#   'phase3_worse_percentage': 0.28},
#  {'id': '12148848',
#   'estimated_population': 267852,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#FAE61E',
#   'anl_id': '12148833',
#   'title': 'Grande-anse ht08',
#   'overall_phase': 2,
#   'phases': [{'phase': 2,
#     'population': 74999,
#     'percent': 0.28,
#     'color': '#FAE61E'},
#    {'phase': 3, 'population': 29464, 'percent': 0.11, 'color': '#E67800'},
#    {'phase': 4, 'population': 5357, 'percent': 0.02, 'color': '#C80000'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 1, 'population': 152676, 'percent': 0.57, 'color': '#CDFACD'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 36160,
#   'phase3_worse_percentage': 0.13},
#  {'id': '12148839',
#   'estimated_population': 678576,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#FAE61E',
#   'anl_id': '12148833',
#   'title': 'La gonave & artibon ht01',
#   'overall_phase': 2,
#   'phases': [{'phase': 2,
#     'population': 332502,
#     'percent': 0.49,
#     'color': '#FAE61E'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 3, 'population': 122144, 'percent': 0.18, 'color': '#E67800'},
#    {'phase': 1, 'population': 217144, 'percent': 0.32, 'color': '#CDFACD'},
#    {'phase': 4, 'population': 6786, 'percent': 0.01, 'color': '#C80000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 128930,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12148857',
#   'estimated_population': 157903,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#FAE61E',
#   'anl_id': '12148833',
#   'title': 'Nippes ht01',
#   'overall_phase': 2,
#   'phases': [{'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 1, 'population': 88426, 'percent': 0.56, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 47371, 'percent': 0.3, 'color': '#FAE61E'},
#    {'phase': 3, 'population': 17369, 'percent': 0.11, 'color': '#E67800'},
#    {'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 20053,
#   'phase3_worse_percentage': 0.11},
#  {'id': '12148860',
#   'estimated_population': 167769,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#FAE61E',
#   'anl_id': '12148833',
#   'title': 'Nippes ht07',
#   'overall_phase': 2,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 3, 'population': 30198, 'percent': 0.18, 'color': '#E67800'},
#    {'phase': 1, 'population': 93951, 'percent': 0.56, 'color': '#CDFACD'},
#    {'phase': 2, 'population': 40265, 'percent': 0.24, 'color': '#FAE61E'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 31876,
#   'phase3_worse_percentage': 0.18},
#  {'id': '12148863',
#   'estimated_population': 367038,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#E67800',
#   'anl_id': '12148833',
#   'title': 'Nord-est ht02',
#   'overall_phase': 3,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 33033, 'percent': 0.09, 'color': '#C80000'},
#    {'phase': 3, 'population': 80748, 'percent': 0.22, 'color': '#E67800'},
#    {'phase': 2, 'population': 154156, 'percent': 0.42, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 99100, 'percent': 0.27, 'color': '#CDFACD'}],
#   'country': 'HT',
#   'year': 2017,
#   'condition': 'A',
#   'phase3_worse_population': 115599,
#   'phase3_worse_percentage': 0.31},
#  {'id': '12148871',
#   'estimated_population': 330098,
#   'period': 'C',
#   'from': 'Oct 2017',
#   'to': 'Feb 2018',
#   'color': '#FAE61E',
#   'anl_id': '12148833',
#   'title': 'Nord-ouest ht01',
#   'overall_phase': 2,
#   'phases': [{'phase': 5, 'population': 0, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 0, 'percent': 0, 'color': '#C80000'},
#    {'phase': 2, 'population': 122136, 'percent': 0.37, 'color': '#FAE61E'},
# ...
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 17088,
#   'phase3_worse_percentage': 0.44},
#  {'id': '12836905',
#   'estimated_population': 119190,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Ceel afweyn',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 18198,
#     'percent': 0.15,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 24779, 'percent': 0.21, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 76213, 'percent': 0.64, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 18198,
#   'phase3_worse_percentage': 0.15},
#  {'id': '12836963',
#   'estimated_population': 75285,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Ceel buur',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 12717,
#     'percent': 0.17,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 26407, 'percent': 0.35, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 36161, 'percent': 0.48, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 12717,
#   'phase3_worse_percentage': 0.17},
#  {'id': '12836977',
#   'estimated_population': 42841,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Ceel waaq',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 2835,
#     'percent': 0.07,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 10310, 'percent': 0.24, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 29696, 'percent': 0.69, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 2835,
#   'phase3_worse_percentage': 0.07},
#  {'id': '12836939',
#   'estimated_population': 186215,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Ceerigaabo',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 26877,
#     'percent': 0.14,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 44492, 'percent': 0.24, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 114846, 'percent': 0.62, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 26877,
#   'phase3_worse_percentage': 0.14},
#  {'id': '12836961',
#   'estimated_population': 134133,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#E67800',
#   'anl_id': '12836822',
#   'title': 'Dhuusamarreeb',
#   'overall_phase': 3,
#   'phases': [{'phase': 5, 'population': 307, 'percent': 0, 'color': '#640000'},
#    {'phase': 4, 'population': 921, 'percent': 0.01, 'color': '#C80000'},
#    {'phase': 3, 'population': 32091, 'percent': 0.24, 'color': '#E67800'},
#    {'phase': 2, 'population': 32124, 'percent': 0.24, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 68689, 'percent': 0.51, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 33319,
#   'phase3_worse_percentage': 0.25},
#  {'id': '12836957',
#   'estimated_population': 70367,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#E67800',
#   'anl_id': '12836822',
#   'title': 'Doolow',
#   'overall_phase': 3,
#   'phases': [{'phase': 4,
#     'population': 5170,
#     'percent': 0.07,
#     'color': '#C80000'},
#    {'phase': 3, 'population': 24574, 'percent': 0.35, 'color': '#E67800'},
#    {'phase': 2, 'population': 23807, 'percent': 0.34, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 16816, 'percent': 0.24, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 29744,
#   'phase3_worse_percentage': 0.42},
#  {'id': '12836947',
#   'estimated_population': 92352,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Eyl',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 8328,
#     'percent': 0.09,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 23259, 'percent': 0.25, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 60765, 'percent': 0.66, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 8328,
#   'phase3_worse_percentage': 0.09},
#  {'id': '12836900',
#   'estimated_population': 420293,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Gaalkacyo',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 80851,
#     'percent': 0.19,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 136071, 'percent': 0.32, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 203372, 'percent': 0.48, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 80851,
#   'phase3_worse_percentage': 0.19},
#  {'id': '12836871',
#   'estimated_population': 96229,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Galdogob',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 8468,
#     'percent': 0.09,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 24635, 'percent': 0.26, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 63127, 'percent': 0.66, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 8468,
#   'phase3_worse_percentage': 0.09},
#  {'id': '12836981',
#   'estimated_population': 150445,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Garbahaarey',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 3433,
#     'percent': 0.02,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 35967, 'percent': 0.24, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 111046, 'percent': 0.74, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 3433,
#   'phase3_worse_percentage': 0.02},
#  {'id': '12836959',
#   'estimated_population': 238944,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Garoowe',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 15219,
#     'percent': 0.06,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 53983, 'percent': 0.23, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 169742, 'percent': 0.71, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 15219,
#   'phase3_worse_percentage': 0.06},
#  {'id': '12836983',
#   'estimated_population': 103449,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#E67800',
#   'anl_id': '12836822',
#   'title': 'Gebiley',
#   'overall_phase': 3,
#   'phases': [{'phase': 3,
#     'population': 22457,
#     'percent': 0.22,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 22731, 'percent': 0.22, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 58261, 'percent': 0.56, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 22457,
#   'phase3_worse_percentage': 0.22},
#  {'id': '12836867',
#   'estimated_population': 90080,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Hobyo',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 13680,
#     'percent': 0.15,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 17692, 'percent': 0.2, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 58708, 'percent': 0.65, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 13680,
#   'phase3_worse_percentage': 0.15},
#  {'id': '12836853',
#   'estimated_population': 137167,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Jalalaqsi',
#   'overall_phase': 2,
#   'phases': [{'phase': 4,
#     'population': 1063,
#     'percent': 0.01,
#     'color': '#C80000'},
#    {'phase': 3, 'population': 10854, 'percent': 0.08, 'color': '#E67800'},
#    {'phase': 2, 'population': 25558, 'percent': 0.19, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 99692, 'percent': 0.73, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 11917,
#   'phase3_worse_percentage': 0.09},
#  {'id': '12836902',
#   'estimated_population': 72274,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Jamaame',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 5808,
#     'percent': 0.08,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 21484, 'percent': 0.3, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 44983, 'percent': 0.62, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 5808,
#   'phase3_worse_percentage': 0.08},
#  {'id': '12836949',
#   'estimated_population': 77165,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Jariiban',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 9806,
#     'percent': 0.13,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 17251, 'percent': 0.22, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 50107, 'percent': 0.65, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 9806,
#   'phase3_worse_percentage': 0.13},
#  {'id': '12836951',
#   'estimated_population': 177364,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Jilib',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 13747,
#     'percent': 0.08,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 44102, 'percent': 0.25, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 119515, 'percent': 0.67, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 13747,
#   'phase3_worse_percentage': 0.08},
#  {'id': '12836834',
#   'estimated_population': 183043,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Jowhar',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 5757,
#     'percent': 0.03,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 40341, 'percent': 0.22, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 136945, 'percent': 0.75, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 5757,
#   'phase3_worse_percentage': 0.03},
#  {'id': '12836945',
#   'estimated_population': 194983,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#E67800',
#   'anl_id': '12836822',
#   'title': 'Kismaayo',
#   'overall_phase': 3,
#   'phases': [{'phase': 4,
#     'population': 11310,
#     'percent': 0.06,
#     'color': '#C80000'},
#    {'phase': 3, 'population': 66401, 'percent': 0.34, 'color': '#E67800'},
#    {'phase': 2, 'population': 50090, 'percent': 0.26, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 67182, 'percent': 0.34, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 77711,
#   'phase3_worse_percentage': 0.4},
#  {'id': '12836989',
#   'estimated_population': 220788,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#E67800',
#   'anl_id': '12836822',
#   'title': 'Laas caanood',
#   'overall_phase': 3,
#   'phases': [{'phase': 3,
#     'population': 90327,
#     'percent': 0.41,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 41254, 'percent': 0.19, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 89208, 'percent': 0.4, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 90327,
#   'phase3_worse_percentage': 0.41},
#  {'id': '12836926',
#   'estimated_population': 238719,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Laasqoray',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 35562,
#     'percent': 0.15,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 44655, 'percent': 0.19, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 158502, 'percent': 0.66, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 35562,
#   'phase3_worse_percentage': 0.15},
#  {'id': '12836965',
#   'estimated_population': 99442,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#E67800',
#   'anl_id': '12836822',
#   'title': 'Lughaye',
#   'overall_phase': 3,
#   'phases': [{'phase': 3,
#     'population': 40670,
#     'percent': 0.41,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 17402, 'percent': 0.17, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 41371, 'percent': 0.42, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 40670,
#   'phase3_worse_percentage': 0.41},
#  {'id': '12836864',
#   'estimated_population': 42201,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Luuq',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 2583,
#     'percent': 0.06,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 9594, 'percent': 0.23, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 30024, 'percent': 0.71, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 2583,
#   'phase3_worse_percentage': 0.06},
#  {'id': '12836967',
#   'estimated_population': 197917,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Marka',
#   'overall_phase': 2,
#   'phases': [{'phase': 2,
#     'population': 72581,
#     'percent': 0.37,
#     'color': '#FAE61E'},
#    {'phase': 1, 'population': 125336, 'percent': 0.63, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 0,
#   'phase3_worse_percentage': 0},
#  {'id': '12836953',
#   'estimated_population': 99752,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Owdweyne',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 9682,
#     'percent': 0.1,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 33246, 'percent': 0.33, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 56824, 'percent': 0.57, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 9682,
#   'phase3_worse_percentage': 0.1},
#  {'id': '12836937',
#   'estimated_population': 50358,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Qandala',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 3875,
#     'percent': 0.08,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 12747, 'percent': 0.25, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 33737, 'percent': 0.67, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 3875,
#   'phase3_worse_percentage': 0.08},
#  {'id': '12836850',
#   'estimated_population': 69363,
#   'period': 'C',
#   'from': 'Jul 2018',
#   'to': 'Jul 2018',
#   'color': '#FAE61E',
#   'anl_id': '12836822',
#   'title': 'Qansax dheere',
#   'overall_phase': 2,
#   'phases': [{'phase': 3,
#     'population': 7446,
#     'percent': 0.11,
#     'color': '#E67800'},
#    {'phase': 2, 'population': 14485, 'percent': 0.21, 'color': '#FAE61E'},
#    {'phase': 1, 'population': 47432, 'percent': 0.68, 'color': '#CDFACD'}],
#   'country': 'SO',
#   'year': 2018,
#   'condition': 'A',
#   'phase3_worse_population': 7446,
#   'phase3_worse_percentage': 0.11},
#  ...]

# %%
# create dataframe from all_areas_df where country matches UG
eth_df = all_areas_df[all_areas_df["country"] == "ET"]
eth_df
# Out:
#             id  estimated_population period      from        to    color  \
# 2593  13963757                795018      C  Jul 2019  Sep 2019  #E67800
# 2594  13963759                193592      C  Jul 2019  Sep 2019  #E67800
# 2595  13963761                501539      C  Jul 2019  Sep 2019  #E67800
# 2596  13963755                 78728      C  Jul 2019  Sep 2019  #FAE61E
# 2597  13963749                479938      C  Jul 2019  Sep 2019  #E67800
# ...        ...                   ...    ...       ...       ...      ...
# 6907  25133946                490664      C  May 2021  Jun 2021  #E67800
# 6908  25133948                478326      C  May 2021  Jun 2021  #E67800
# 6909  25133972                189681      C  May 2021  Jun 2021  #E67800
# 6910  25133922                274885      C  May 2021  Jun 2021  #E67800
# 6911  25133958                190303      C  May 2021  Jun 2021  #E67800
#
#         anl_id                                           title  overall_phase  \
# 2593  13963677        ABB - Abay-Beshilo Basin Livelihood Zone              3
# 2594  13963677            Abm-Alaba-Badewacho-Maize Livelihood              3
# 2595  13963677            AFP - Afder Pastoral Livelihood Zone              3
# 2596  13963677  AGA - Awsa Gewane Agropastoral Livelihood Zone              2
# 2597  13963677      ARP - Aramis-Adar Pastoral Livelihood Zone              3
# ...        ...                                             ...            ...
# 6907  25133691                              Zone 1 (awsi rasu)              3
# 6908  25133691                            Zone 2 (kilbet rasu)              3
# 6909  25133691                              Zone 3 (gabi rasu)              3
# 6910  25133691                           Zone 4 (fantana rasu)              3
# 6911  25133691                              Zone 5 (hari rasu)              3
#
#                                                  phases country  year  \
# 2593  [{'phase': 1, 'population': 477011, 'percent':...      ET  2019
# 2594  [{'phase': 3, 'population': 38718, 'percent': ...      ET  2019
# 2595  [{'phase': 3, 'population': 150462, 'percent':...      ET  2019
# 2596  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2019
# 2597  [{'phase': 2, 'population': 143981, 'percent':...      ET  2019
# ...                                                 ...     ...   ...
# 6907  [{'phase': 1, 'population': 98133, 'percent': ...      ET  2021
# 6908  [{'phase': 1, 'population': 47833, 'percent': ...      ET  2021
# 6909  [{'phase': 1, 'population': 47420, 'percent': ...      ET  2021
# 6910  [{'phase': 1, 'population': 41233, 'percent': ...      ET  2021
# 6911  [{'phase': 1, 'population': 47576, 'percent': ...      ET  2021
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 2593         A                   159002                     0.20
# 2594         A                    48397                     0.25
# 2595         A                   175537                     0.35
# 2596         A                     7872                     0.10
# 2597         A                    95986                     0.20
# ...        ...                      ...                      ...
# 6907         A                        0                     0.00
# 6908         A                        0                     0.00
# 6909         A                        0                     0.00
# 6910         A                        0                     0.00
# 6911         A                        0                     0.00
#
# [288 rows x 15 columns]

# %%
# sort eth_df by year
eth_df = eth_df.sort_values(by="title")
eth_df
# Out:
#             id  estimated_population period      from        to    color  \
# 2604  13963712                 84784      C  Jul 2019  Sep 2019  #E67800
# 2593  13963757                795018      C  Jul 2019  Sep 2019  #E67800
# 2595  13963761                501539      C  Jul 2019  Sep 2019  #E67800
# 2596  13963755                 78728      C  Jul 2019  Sep 2019  #FAE61E
# 2612  13963733                413919      C  Jul 2019  Sep 2019  #E67800
# ...        ...                   ...    ...       ...       ...      ...
# 4272  18550009                257449      C  Jul 2020  Sep 2020  #E67800
# 6910  25133922                274885      C  May 2021  Jun 2021  #E67800
# 4937  19423761                186917      C  Oct 2020  Dec 2020  #E67800
# 4273  18550007                274937      C  Jul 2020  Sep 2020  #FAE61E
# 6911  25133958                190303      C  May 2021  Jun 2021  #E67800
#
#         anl_id                                           title  overall_phase  \
# 2604  13963677       AAP - Assale Agropastoral Livelihood Zone              3
# 2593  13963677        ABB - Abay-Beshilo Basin Livelihood Zone              3
# 2595  13963677            AFP - Afder Pastoral Livelihood Zone              3
# 2596  13963677  AGA - Awsa Gewane Agropastoral Livelihood Zone              2
# 2612  13963677              AMP Alaba-Mareko Lowland Pepper LZ              3
# ...        ...                                             ...            ...
# 4272  18549989                           Zone 4 (fantana rasu)              3
# 6910  25133691                           Zone 4 (fantana rasu)              3
# 4937  19423617                              Zone 5 (hari rasu)              3
# 4273  18549989                              Zone 5 (hari rasu)              2
# 6911  25133691                              Zone 5 (hari rasu)              3
#
#                                                  phases country  year  \
# 2604  [{'phase': 3, 'population': 21196, 'percent': ...      ET  2019
# 2593  [{'phase': 1, 'population': 477011, 'percent':...      ET  2019
# 2595  [{'phase': 3, 'population': 150462, 'percent':...      ET  2019
# 2596  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2019
# 2612  [{'phase': 3, 'population': 82784, 'percent': ...      ET  2019
# ...                                                 ...     ...   ...
# 4272  [{'phase': 1, 'population': 115852, 'percent':...      ET  2020
# 6910  [{'phase': 1, 'population': 41233, 'percent': ...      ET  2021
# 4937  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2020
# 4273  [{'phase': 2, 'population': 96228, 'percent': ...      ET  2020
# 6911  [{'phase': 1, 'population': 47576, 'percent': ...      ET  2021
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 2604         A                    21196                     0.25
# 2593         A                   159002                     0.20
# 2595         A                   175537                     0.35
# 2596         A                     7872                     0.10
# 2612         A                   103478                     0.25
# ...        ...                      ...                      ...
# 4272         A                        0                     0.00
# 6910         A                        0                     0.00
# 4937         A                        0                     0.00
# 4273         A                        0                     0.00
# 6911         A                        0                     0.00
#
# [288 rows x 15 columns]

# %%
# plot how many times each region was measured in eth_df
eth_hist = px.histogram(eth_df["title"], x=eth_df["title"])
eth_hist.update_xaxes(title_text="Region")
eth_hist.show()

# %%
# return eth_df with no limit on rows shown
pd.set_option('display.max_rows', none)
eth_df
# Out:
#             id  estimated_population period      from        to    color  \
# 2604  13963712                 84784      C  Jul 2019  Sep 2019  #E67800
# 2593  13963757                795018      C  Jul 2019  Sep 2019  #E67800
# 2595  13963761                501539      C  Jul 2019  Sep 2019  #E67800
# 2596  13963755                 78728      C  Jul 2019  Sep 2019  #FAE61E
# 2612  13963733                413919      C  Jul 2019  Sep 2019  #E67800
# ...        ...                   ...    ...       ...       ...      ...
# 4272  18550009                257449      C  Jul 2020  Sep 2020  #E67800
# 6910  25133922                274885      C  May 2021  Jun 2021  #E67800
# 4937  19423761                186917      C  Oct 2020  Dec 2020  #E67800
# 4273  18550007                274937      C  Jul 2020  Sep 2020  #FAE61E
# 6911  25133958                190303      C  May 2021  Jun 2021  #E67800
#
#         anl_id                                           title  overall_phase  \
# 2604  13963677       AAP - Assale Agropastoral Livelihood Zone              3
# 2593  13963677        ABB - Abay-Beshilo Basin Livelihood Zone              3
# 2595  13963677            AFP - Afder Pastoral Livelihood Zone              3
# 2596  13963677  AGA - Awsa Gewane Agropastoral Livelihood Zone              2
# 2612  13963677              AMP Alaba-Mareko Lowland Pepper LZ              3
# ...        ...                                             ...            ...
# 4272  18549989                           Zone 4 (fantana rasu)              3
# 6910  25133691                           Zone 4 (fantana rasu)              3
# 4937  19423617                              Zone 5 (hari rasu)              3
# 4273  18549989                              Zone 5 (hari rasu)              2
# 6911  25133691                              Zone 5 (hari rasu)              3
#
#                                                  phases country  year  \
# 2604  [{'phase': 3, 'population': 21196, 'percent': ...      ET  2019
# 2593  [{'phase': 1, 'population': 477011, 'percent':...      ET  2019
# 2595  [{'phase': 3, 'population': 150462, 'percent':...      ET  2019
# 2596  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2019
# 2612  [{'phase': 3, 'population': 82784, 'percent': ...      ET  2019
# ...                                                 ...     ...   ...
# 4272  [{'phase': 1, 'population': 115852, 'percent':...      ET  2020
# 6910  [{'phase': 1, 'population': 41233, 'percent': ...      ET  2021
# 4937  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2020
# 4273  [{'phase': 2, 'population': 96228, 'percent': ...      ET  2020
# 6911  [{'phase': 1, 'population': 47576, 'percent': ...      ET  2021
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 2604         A                    21196                     0.25
# 2593         A                   159002                     0.20
# 2595         A                   175537                     0.35
# 2596         A                     7872                     0.10
# 2612         A                   103478                     0.25
# ...        ...                      ...                      ...
# 4272         A                        0                     0.00
# 6910         A                        0                     0.00
# 4937         A                        0                     0.00
# 4273         A                        0                     0.00
# 6911         A                        0                     0.00
#
# [288 rows x 15 columns]

# %%
# return all indpendent values in eth_df 'from' colum
eth_df["from"].unique()
# Out:
# array(['Jul 2019', 'Oct 2020', 'May 2021', 'Jul 2020'], dtype=object)

# %%
# create a bar chart of eth_df phase3_worse_percentage
eth_bar = px.bar(eth_df, x="title", y="phase3_worse_percentage")

# %%
# create a df for each value in eth_df["from"]
ethjul19 = eth_df[eth_df["from"] == "Jul 2019"]
ethhoct20 = eth_df[eth_df["from"] == "Oct 2020"]
ethmay21 = eth_df[eth_df["from"] == "May 2021"]
ethjul20 = eth_df[eth_df["from"] == "Jul 2020"]

# %%
ethjul19
# Out:
#             id  estimated_population period      from        to    color  \
# 2604  13963712                 84784      C  Jul 2019  Sep 2019  #E67800
# 2593  13963757                795018      C  Jul 2019  Sep 2019  #E67800
# 2595  13963761                501539      C  Jul 2019  Sep 2019  #E67800
# 2596  13963755                 78728      C  Jul 2019  Sep 2019  #FAE61E
# 2612  13963733                413919      C  Jul 2019  Sep 2019  #E67800
# ...        ...                   ...    ...       ...       ...      ...
# 2677  13963857                123628      C  Jul 2019  Sep 2019  #E67800
# 2678  13963861                142834      C  Jul 2019  Sep 2019  #FAE61E
# 2679  13963863                628793      C  Jul 2019  Sep 2019  #E67800
# 2680  13963859                246718      C  Jul 2019  Sep 2019  #E67800
# 2676  13963855                677555      C  Jul 2019  Sep 2019  #E67800
#
#         anl_id                                           title  overall_phase  \
# 2604  13963677       AAP - Assale Agropastoral Livelihood Zone              3
# 2593  13963677        ABB - Abay-Beshilo Basin Livelihood Zone              3
# 2595  13963677            AFP - Afder Pastoral Livelihood Zone              3
# 2596  13963677  AGA - Awsa Gewane Agropastoral Livelihood Zone              2
# 2612  13963677              AMP Alaba-Mareko Lowland Pepper LZ              3
# ...        ...                                             ...            ...
# 2677  13963677               WCG Wolayita Ginger and Coffee LZ              3
# 2678  13963677  WMB - South Wollo Meher & Belg Livelihood Zone              2
# 2679  13963677             WMR Wolayita Maize and Root Crop LZ              3
# 2680  13963677                WWB Wolayita Barley and Wheat LZ              3
# 2676  13963677                    Wbp- Wheat Barely and Potato              3
#
#                                                  phases country  year  \
# 2604  [{'phase': 3, 'population': 21196, 'percent': ...      ET  2019
# 2593  [{'phase': 1, 'population': 477011, 'percent':...      ET  2019
# 2595  [{'phase': 3, 'population': 150462, 'percent':...      ET  2019
# 2596  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2019
# 2612  [{'phase': 3, 'population': 82784, 'percent': ...      ET  2019
# ...                                                 ...     ...   ...
# 2677  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2019
# 2678  [{'phase': 1, 'population': 85700, 'percent': ...      ET  2019
# 2679  [{'phase': 4, 'population': 31440, 'percent': ...      ET  2019
# 2680  [{'phase': 3, 'population': 37008, 'percent': ...      ET  2019
# 2676  [{'phase': 3, 'population': 169389, 'percent':...      ET  2019
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 2604         A                    21196                     0.25
# 2593         A                   159002                     0.20
# 2595         A                   175537                     0.35
# 2596         A                     7872                     0.10
# 2612         A                   103478                     0.25
# ...        ...                      ...                      ...
# 2677         A                    30906                     0.25
# 2678         A                    21424                     0.15
# 2679         A                   157197                     0.25
# 2680         A                    49342                     0.20
# 2676         A                   203265                     0.30
#
# [88 rows x 15 columns]

# %%
ethhoct20
# Out:
#             id  estimated_population period      from        to    color  \
# 4862  19423626                587747      C  Oct 2020  Dec 2020  #E67800
# 4863  19423629               3156594      C  Oct 2020  Dec 2020  #FAE61E
# 4864  19423634               1619663      C  Oct 2020  Dec 2020  #E67800
# 4865  19423636                488901      C  Oct 2020  Dec 2020  #E67800
# 4868  19423643                399805      C  Oct 2020  Dec 2020  #FAE61E
# ...        ...                   ...    ...       ...       ...      ...
# 4933  19423753                481894      C  Oct 2020  Dec 2020  #E67800
# 4934  19423755                433499      C  Oct 2020  Dec 2020  #E67800
# 4935  19423757                186292      C  Oct 2020  Dec 2020  #E67800
# 4936  19423759                258724      C  Oct 2020  Dec 2020  #E67800
# 4937  19423761                186917      C  Oct 2020  Dec 2020  #E67800
#
#         anl_id                      title  overall_phase  \
# 4862  19423617                      Afder              3
# 4863  19423617                       Arsi              2
# 4864  19423617                       Bale              3
# 4865  19423617                     Borena              3
# 4868  19423617  Central gondar, cluster 1              2
# ...        ...                        ...            ...
# 4933  19423617         Zone 1 (awsi rasu)              3
# 4934  19423617       Zone 2 (kilbet rasu)              3
# 4935  19423617         Zone 3 (gabi rasu)              3
# 4936  19423617      Zone 4 (fantana rasu)              3
# 4937  19423617         Zone 5 (hari rasu)              3
#
#                                                  phases country  year  \
# 4862  [{'phase': 1, 'population': 176324, 'percent':...      ET  2020
# 4863  [{'phase': 1, 'population': 1736127, 'percent'...      ET  2020
# 4864  [{'phase': 3, 'population': 323933, 'percent':...      ET  2020
# 4865  [{'phase': 1, 'population': 171115, 'percent':...      ET  2020
# 4868  [{'phase': 4, 'population': 0, 'percent': 0, '...      ET  2020
# ...                                                 ...     ...   ...
# 4933  [{'phase': 3, 'population': 192758, 'percent':...      ET  2020
# 4934  [{'phase': 3, 'population': 151725, 'percent':...      ET  2020
# 4935  [{'phase': 1, 'population': 37258, 'percent': ...      ET  2020
# 4936  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2020
# 4937  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2020
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 4862         A                        0                      0.0
# 4863         A                        0                      0.0
# 4864         A                        0                      0.0
# 4865         A                        0                      0.0
# 4868         A                        0                      0.0
# ...        ...                      ...                      ...
# 4933         A                        0                      0.0
# 4934         A                        0                      0.0
# 4935         A                        0                      0.0
# 4936         A                        0                      0.0
# 4937         A                        0                      0.0
#
# [76 rows x 15 columns]

# %%
ethmay21
# Out:
#             id  estimated_population period      from        to    color  \
# 6849  25133868                603209      C  May 2021  Jun 2021  #E67800
# 6851  25133872               3227606      C  May 2021  Jun 2021  #E67800
# 6847  25133855               1656072      C  May 2021  Jun 2021  #E67800
# 6854  25133938                499899      C  May 2021  Jun 2021  #E67800
# 6853  25133878                404184      C  May 2021  Jun 2021  #FAE61E
# ...        ...                   ...    ...       ...       ...      ...
# 6908  25133948                478326      C  May 2021  Jun 2021  #E67800
# 6909  25133972                189681      C  May 2021  Jun 2021  #E67800
# 6122  24026112                274885      C  May 2021  Jun 2021  #E67800
# 6910  25133922                274885      C  May 2021  Jun 2021  #E67800
# 6911  25133958                190303      C  May 2021  Jun 2021  #E67800
#
#         anl_id                      title  overall_phase  \
# 6849  25133691                      Afder              3
# 6851  25133691                       Arsi              3
# 6847  25133691                       Bale              3
# 6854  25133691                     Borena              3
# 6853  25133691  Central gondar, cluster 1              2
# ...        ...                        ...            ...
# 6908  25133691       Zone 2 (kilbet rasu)              3
# 6909  25133691         Zone 3 (gabi rasu)              3
# 6122  24026108      Zone 4 (fantana rasu)              3
# 6910  25133691      Zone 4 (fantana rasu)              3
# 6911  25133691         Zone 5 (hari rasu)              3
#
#                                                  phases country  year  \
# 6849  [{'phase': 1, 'population': 120642, 'percent':...      ET  2021
# 6851  [{'phase': 1, 'population': 1452423, 'percent'...      ET  2021
# 6847  [{'phase': 1, 'population': 662429, 'percent':...      ET  2021
# 6854  [{'phase': 1, 'population': 124975, 'percent':...      ET  2021
# 6853  [{'phase': 1, 'population': 202092, 'percent':...      ET  2021
# ...                                                 ...     ...   ...
# 6908  [{'phase': 1, 'population': 47833, 'percent': ...      ET  2021
# 6909  [{'phase': 1, 'population': 47420, 'percent': ...      ET  2021
# 6122  [{'phase': 3, 'population': 137443, 'percent':...      ET  2021
# 6910  [{'phase': 1, 'population': 41233, 'percent': ...      ET  2021
# 6911  [{'phase': 1, 'population': 47576, 'percent': ...      ET  2021
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 6849         A                        0                      0.0
# 6851         A                        0                      0.0
# 6847         A                        0                      0.0
# 6854         A                        0                      0.0
# 6853         A                        0                      0.0
# ...        ...                      ...                      ...
# 6908         A                        0                      0.0
# 6909         A                        0                      0.0
# 6122         A                        0                      0.0
# 6910         A                        0                      0.0
# 6911         A                        0                      0.0
#
# [85 rows x 15 columns]

# %%
ethjul20
# Out:
#             id  estimated_population period      from        to    color  \
# 4235  18550075                590566      C  Jul 2020  Sep 2020  #E67800
# 4236  18549998               3124850      C  Jul 2020  Sep 2020  #FAE61E
# 4237  18550073               1604521      C  Jul 2020  Sep 2020  #E67800
# 4238  18550071                483985      C  Jul 2020  Sep 2020  #E67800
# 4239  18550069                412269      C  Jul 2020  Sep 2020  #E67800
# ...        ...                   ...    ...       ...       ...      ...
# 4269  18550015                391597      C  Jul 2020  Sep 2020  #E67800
# 4270  18550013                431266      C  Jul 2020  Sep 2020  #E67800
# 4271  18550011                185304      C  Jul 2020  Sep 2020  #E67800
# 4272  18550009                257449      C  Jul 2020  Sep 2020  #E67800
# 4273  18550007                274937      C  Jul 2020  Sep 2020  #FAE61E
#
#         anl_id                  title  overall_phase  \
# 4235  18549989                  Afder              3
# 4236  18549989                   Arsi              2
# 4237  18549989                   Bale              3
# 4238  18549989                 Borena              3
# 4239  18549989                  Daawa              3
# ...        ...                    ...            ...
# 4269  18549989     Zone 1 (awsi rasu)              3
# 4270  18549989   Zone 2 (kilbet rasu)              3
# 4271  18549989     Zone 3 (gabi rasu)              3
# 4272  18549989  Zone 4 (fantana rasu)              3
# 4273  18549989     Zone 5 (hari rasu)              2
#
#                                                  phases country  year  \
# 4235  [{'phase': 3, 'population': 236226, 'percent':...      ET  2020
# 4236  [{'phase': 1, 'population': 1562425, 'percent'...      ET  2020
# 4237  [{'phase': 4, 'population': 80226, 'percent': ...      ET  2020
# 4238  [{'phase': 4, 'population': 24199, 'percent': ...      ET  2020
# 4239  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2020
# ...                                                 ...     ...   ...
# 4269  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2020
# 4270  [{'phase': 5, 'population': 0, 'percent': 0, '...      ET  2020
# 4271  [{'phase': 4, 'population': 9265, 'percent': 0...      ET  2020
# 4272  [{'phase': 1, 'population': 115852, 'percent':...      ET  2020
# 4273  [{'phase': 2, 'population': 96228, 'percent': ...      ET  2020
#
#      condition  phase3_worse_population  phase3_worse_percentage
# 4235         A                        0                      0.0
# 4236         A                        0                      0.0
# 4237         A                        0                      0.0
# 4238         A                        0                      0.0
# 4239         A                        0                      0.0
# ...        ...                      ...                      ...
# 4269         A                        0                      0.0
# 4270         A                        0                      0.0
# 4271         A                        0                      0.0
# 4272         A                        0                      0.0
# 4273         A                        0                      0.0
#
# [39 rows x 15 columns]
