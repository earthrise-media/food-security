# %%
import numpy as np
import pandas as pd
import requests
import geopandas as gpd
from datetime import date
import json

# %% [markdown]
# *URL from Comtrade website used in request*
# https://comtrade.un.org/api/get?max=502&type=C&freq=A&px=HS&ps=2021&r=586&p=all&rg=1&cc=10&uitoken=6114b63f039a10acb9989163d112ca5e
#
# Parameters used:
#
# year = 2021
#
# partners = all
#
# Trade flows = Imports
#
# commodity = 10 - cereals
#
# frequency =  annual
#
# Documentation: https://comtrade.un.org/data/doc/api/#DataRequests

# %%
# from requests.auth import HTTPBasicAuth
# function that gets data from USDA endpoint and converts response to pandas dataframe
def get_usda_data(endpoint_url):
    # USDA API Key
    key = {"API_KEY": "aefd68b9-cfdc-4c9e-a800-b457ff5adade"}
    request = requests.get(url=endpoint_url, headers=key)
    # convert response to pandas dataframe
    return (pd.read_json(request.text))

# %%
# from requests.auth import HTTPBasicAuth
# function that gets data from USDA endpoint and converts response to pandas dataframe
def get_comtrade_data(endpoint_url):
    request = requests.get(url=endpoint_url)
    # convert response to pandas dataframe
    return (pd.json_normalize(request.json()["dataset"]))

# %%
# documentation here: https://comtrade.un.org/data/doc/api/#DataRequests
url = "https://comtrade.un.org/api/get?max={max}&type={type}"
url = "https://comtrade.un.org/api/get?max={max}&type={type}&freq={frequency}&px=HS&ps=2021&r=586&p=all&rg=1&cc=10&uitoken=6114b63f039a10acb9989163d112ca5e"

"/api/get?max=502&type=C&freq=A&px=HS&ps=2021&r=586&p=all&rg=1&cc=10"

max = "502" #maximum records returned (max 250,000)
type = "C" #trade data type (commodity or service)
freq = "A" #data set frequency (annual or monthly)
px = "HS" #classification
ps = "2021" #time period multiple years format is "2013%2C2012%2C2011%2C2010%2C2009"
r = "586" #reporting area
p = "all" #partner area
rg = "1" #trade regime
cc = "10" #commodity classification code
uitoken = "6114b63f039a10acb9989163d112ca5e" #authorization code I don't think I need this

# %%
endpoint_url = "https://comtrade.un.org/api/get?max=502&type=C&freq=A&px=HS&ps=2021&r=586&p=all&rg=1&cc=10"
request = requests.get(url=endpoint_url)
dvar = request.text
type(dvar)
# Out:
# str

# %%
print (request.json()["validation"])

# print(dvar[validation])
# # thisdict["brand"]

# %%
# print(request.text.dataset)
# df1 = pd.read_json(requests.text)

# import json
# import pandas as pd
# data = json.load(open('json_file.json'))

# df = pd.read_json(request.text)
df = pd.json_normalize(request.json()["dataset"])

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#    pfCode    yr  period periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  rtCode  \
# 0      H5  2021    2021       2021          2       0       1  Import     586
# 1      H5  2021    2021       2021          2       0       1  Import     586
# 2      H5  2021    2021       2021          2       0       1  Import     586
# 3      H5  2021    2021       2021          2       0       1  Import     586
# 4      H5  2021    2021       2021          2       0       1  Import     586
# 5      H5  2021    2021       2021          2       0       1  Import     586
# 24  Pakistan    PAK     710          South Africa    ZAF    None
# 25  Pakistan    PAK     764              Thailand    THA    None
# 26  Pakistan    PAK     784  United Arab Emirates    ARE    None
# 27  Pakistan    PAK     792                Turkey    TUR    None
# 28  Pakistan    PAK     795          Turkmenistan    TKM    None
# 29  Pakistan    PAK     804               Ukraine    UKR    None
# 30  Pakistan    PAK     842                   USA    USA    None
# 31  Pakistan    PAK     860            Uzbekistan    UZB    None
#
#    pt3ISO2 cstCode cstDesc motCode motDesc cmdCode cmdDescE  qtCode  \
# 0                                               10  Cereals       1
# 1                                               10  Cereals       1
# 2                                               10  Cereals       1
# 3                                               10  Cereals       1
# 4                                               10  Cereals       1
# 5                                               10  Cereals       1
# 6                                               10  Cereals       1
# 7                                               10  Cereals       1
# 8                                               10  Cereals       1
# 9                                               10  Cereals       1
# 10                                              10  Cereals       1
# 11                                              10  Cereals       1
# 12                                              10  Cereals       1
# 13                                              10  Cereals       1
# 14                                              10  Cereals       1
# 15                                              10  Cereals       1
# 16                                              10  Cereals       1
# 17                                              10  Cereals       1
# 18                                              10  Cereals       1
# 19                                              10  Cereals       1
# 20                                              10  Cereals       1
# 21                                              10  Cereals       1
# 22                                              10  Cereals       1
# 23                                              10  Cereals       1
# 24                                              10  Cereals       1
# 25                                              10  Cereals       1
# 26                                              10  Cereals       1
# 27                                              10  Cereals       1
# 28                                              10  Cereals       1
# 29                                              10  Cereals       1
# 30                                              10  Cereals       1
# 31                                              10  Cereals       1
#
#          qtDesc qtAltCode qtAltDesc  TradeQuantity AltQuantity  NetWeight  \
# 0   No Quantity      None                        0        None          0
# 1   No Quantity      None                        0        None          0
# 2   No Quantity      None                        0        None          0
# 3   No Quantity      None                        0        None          0
# 4   No Quantity      None                        0        None          0
# 5   No Quantity      None                        0        None          0
# 6   No Quantity      None                        0        None          0
# 7   No Quantity      None                        0        None          0
# 8   No Quantity      None                        0        None          0
# 9   No Quantity      None                        0        None          0
# 10  No Quantity      None                        0        None          0
# 11  No Quantity      None                        0        None          0
# 12  No Quantity      None                        0        None          0
# 13  No Quantity      None                        0        None          0
# 14  No Quantity      None                        0        None          0
# 15  No Quantity      None                        0        None          0
# 16  No Quantity      None                        0        None          0
# 17  No Quantity      None                        0        None          0
# 18  No Quantity      None                        0        None          0
# 19  No Quantity      None                        0        None          0
# 20  No Quantity      None                        0        None          0
# 21  No Quantity      None                        0        None          0
# 22  No Quantity      None                        0        None          0
# 23  No Quantity      None                        0        None          0
# 24  No Quantity      None                        0        None          0
# 25  No Quantity      None                        0        None          0
# 26  No Quantity      None                        0        None          0
# 27  No Quantity      None                        0        None          0
# 28  No Quantity      None                        0        None          0
# 29  No Quantity      None                        0        None          0
# 30  No Quantity      None                        0        None          0
# 31  No Quantity      None                        0        None          0
#
#    GrossWeight  TradeValue CIFValue FOBValue  estCode
# 0         None   930742349     None     None        4
# 1         None     1259193     None     None        0
# 2         None    16725193     None     None        0
# 3         None      976115     None     None        0
# 4         None    15914119     None     None        0
# 5         None    91801762     None     None        0
# 6         None      395864     None     None        0
# 7         None        1950     None     None        0
# 8         None    41119067     None     None        0
# 9         None    18819261     None     None        0
# 10        None     9584387     None     None        0
# 11        None         198     None     None        4
# 12        None      846324     None     None        0
# 13        None      572125     None     None        0
# 14        None      484424     None     None        0
# 15        None         992     None     None        0
# 16        None         290     None     None        0
# 17        None           3     None     None        0
# 18        None        7881     None     None        0
# 19        None       17044     None     None        0
# 20        None        1451     None     None        0
# 21        None    18032294     None     None        0
# 22        None   150117919     None     None        0
# 23        None          81     None     None        0
# 24        None        3525     None     None        0
# 25        None    35793706     None     None        0
# 26        None    14760027     None     None        0
# 27        None     1098767     None     None        0
# 28        None       11625     None     None        0
# 29        None   477854607     None     None        0
# 30        None    34533101     None     None        0
# 31        None        9037     None     None        0

# %%
df2 = pd.json_normalize('../pages/assets/reporting_areas.json'.json()["results"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [51], line 1
# ----> 1 df2 = pd.json_normalize('../pages/assets/reporting_areas.json'.json()["results"])
#
# AttributeError: 'str' object has no attribute 'json'

# %%
country_url = "https://comtrade.un.org/Data/cache/reporterAreas.json"
request = requests.get(url=country_url)
# convert response to pandas dataframe
request.encoding='utf-8-sig'
df3 = pd.json_normalize(request.json()["results"])


df3
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/geo/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/geo/lib/python3.10/json/__init__.py:335, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     334     if s.startswith('\ufeff'):
# --> 335         raise JSONDecodeError("Unexpected UTF-8 BOM (decode using utf-8-sig)",
#     336                               s, 0)
#     337 else:
#
# JSONDecodeError: Unexpected UTF-8 BOM (decode using utf-8-sig): line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [52], line 4
#       2 request = requests.get(url=country_url)
#       3 # convert response to pandas dataframe
# ----> 4 df3 = pd.json_normalize(request.json()["results"])
#       5 df3
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/geo/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Unexpected UTF-8 BOM (decode using utf-8-sig): line 1 column 1 (char 0)
